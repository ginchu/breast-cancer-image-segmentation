# %% [markdown]
# <a href="https://colab.research.google.com/github/ginchu/breast-cancer-image-segmentation/blob/main/train_MAnet_noAug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook trains a [Multi-Scale Attention Network (MA-Net)](https://ieeexplore.ieee.org/abstract/document/9201310) model on the non-augmented version of the TNBC_NucleiSegmentation dataset. The MA-Net model implementation used here is provided in the popular [segmentation-models-pytorch library](https://github.com/qubvel/segmentation_models.pytorch).

# %% [markdown]
# ## Setup

# %%
! pip install segmentation-models-pytorch
! pip install wandb
# Out:
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.2.1-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 9.1 MB/s
# Collecting pretrainedmodels==0.7.4
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 7.7 MB/s
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 52.1 MB/s
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from segmentation-models-pytorch) (0.12.0+cu113)
# Collecting efficientnet-pytorch==0.6.3
#   Downloading efficientnet_pytorch-0.6.3.tar.gz (16 kB)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet-pytorch==0.6.3->segmentation-models-pytorch) (1.11.0+cu113)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch) (4.64.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.6.3->segmentation-models-pytorch) (4.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (2.23.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2021.10.8)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.6.3-py3-none-any.whl size=12421 sha256=ce471a0a2e6a2f88ec57eb52ba39b4af2b9edf030653c02327b00f3479c236d5
#   Stored in directory: /root/.cache/pip/wheels/90/6b/0c/f0ad36d00310e65390b0d4c9218ae6250ac579c92540c9097a
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60965 sha256=ec6c74f6f79bec77c05ca9083c0829eaa83439ef4016c90db3de35f22200dd60
#   Stored in directory: /root/.cache/pip/wheels/ed/27/e8/9543d42de2740d3544db96aefef63bda3f2c1761b3334f4873
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, timm, pretrainedmodels, efficientnet-pytorch, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.6.3 munch-2.5.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.2.1 timm-0.4.12
# Collecting wandb
#   Downloading wandb-0.12.16-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 13.0 MB/s
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 46.8 MB/s
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.12-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 56.7 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.2.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.1 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=8af58f9130b128375bc91d6901afb7a7c900577612ef8307ef06f485e3cff084
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.12 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 wandb-0.12.16

# %%
# load repo and data
print('Loading data...')
! git clone https://github.com/ginchu/breast-cancer-image-segmentation.git
print('Done!')

% cd breast-cancer-image-segmentation/
# Out:
# Loading data...
# Cloning into 'breast-cancer-image-segmentation'...
# remote: Enumerating objects: 609, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 609 (delta 0), reused 6 (delta 0), pack-reused 602
# Receiving objects: 100% (609/609), 645.41 MiB | 16.29 MiB/s, done.
# Resolving deltas: 100% (46/46), done.
# Checking out files: 100% (565/565), done.
# Done!
# /content/breast-cancer-image-segmentation

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split

import segmentation_models_pytorch as smp
import data
import aug_data

import wandb

# %%
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
num_epochs = 150
test_split = 0.3
batch_size = 8
#SEED = 42
lr = 0.003

# %% [markdown]
# ## **D**ata

# %%
data = data.Dataset()
print(len(data))
print(data[1][0].shape)
# Out:
# 47
# torch.Size([3, 512, 512])

# %% [markdown]
# Generate train and test indices, then create data loaders for train and test sets

# %%
train_indices, test_indices, _, _ = train_test_split(
    range(len(data)),
    data.y,
    test_size=test_split
)

train = Subset(data, train_indices)
test = Subset(data, test_indices)

train_generator = DataLoader(train, batch_size=batch_size, shuffle=True)
test_generator = DataLoader(test, batch_size=batch_size, shuffle=True)

train_size, test_size = len(train), len(test)
print(train_size, test_size)
# Out:
# 32 15

# %%
# helper function for data visualization
# from https://github.com/qubvel/segmentation_models.pytorch/blob/master/examples/cars%20segmentation%20(camvid).ipynb

def visualize(**images):
    """Plot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

img, mask = data[3]
visualize(
    image=img.permute(2,1,0),
    target_mask=mask.squeeze().permute(1,0)
)

img, mask = data[20]
visualize(
    image=img.permute(2,1,0),
    target_mask=mask.squeeze().permute(1,0)
)

# %% [markdown]
# ## **M**odel

# %%
ENCODER = 'resnet34' # default for MAnet
ENCODER_WEIGHTS = 'imagenet' # default for MAnet

model = smp.MAnet(encoder_name = ENCODER,
                  encoder_weights = ENCODER_WEIGHTS,
                  in_channels = 3,
                  classes = 1,
                  activation = 'sigmoid')

# %% [markdown]
# ## **L**oss

# %%
loss = smp.utils.losses.DiceLoss()

metrics = [
           smp.utils.metrics.IoU(threshold=0.5)
]

# %% [markdown]
# ## **O**ptimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Training loop

# %%
config_dict = dict(
    data = 'noAug',
    epochs = num_epochs,
    batch_size = batch_size,
    dataset_len = len(data),
    test_split = test_split,
    lr = lr
)

wandb.init(project = 'BIA final', entity = 'weiss', config = config_dict)

train_epoch = smp.utils.train.TrainEpoch(
    model,
    loss = loss,
    metrics = metrics,
    optimizer = optimizer,
    device = 'cuda',
    verbose = True
)

tr_loss = []

max_score = 0

for epoch in range(num_epochs):
  
  print('\nEpoch: {}'. format(epoch))

  train_logs = train_epoch.run(train_generator)

  if max_score < train_logs['iou_score']:
    max_score = train_logs['iou_score']
    torch.save(model, './best_MAnet_noAug.pth')
    print('Model saved!')

  tr_loss.append(train_logs)

  wandb.log({'Epoch Dice Loss': train_logs['dice_loss'],
             'Epoch IoU Score': train_logs['iou_score'],
             'Best IoU Score': max_score})
# Out:
# wandb: Currently logged in as: weiss. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/breast-cancer-image-segmentation/wandb/run-20220515_015951-r1oy0eks</code>
# Syncing run <strong><a href="https://wandb.ai/weiss/BIA%20final/runs/r1oy0eks" target="_blank">comfy-monkey-18</a></strong> to <a href="https://wandb.ai/weiss/BIA%20final" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Epoch: 0
# train: 100%|██████████| 4/4 [00:03<00:00,  1.14it/s, dice_loss - 0.6904, iou_score - 0.2707]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 4/4 [00:03<00:00,  1.33it/s, dice_loss - 0.5812, iou_score - 0.4161]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 4/4 [00:03<00:00,  1.33it/s, dice_loss - 0.5256, iou_score - 0.4538]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 4/4 [00:03<00:00,  1.33it/s, dice_loss - 0.4789, iou_score - 0.515]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 4/4 [00:03<00:00,  1.33it/s, dice_loss - 0.3963, iou_score - 0.5822]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 4/4 [00:03<00:00,  1.32it/s, dice_loss - 0.3683, iou_score - 0.5891]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 4/4 [00:03<00:00,  1.33it/s, dice_loss - 0.3089, iou_score - 0.6126]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 4/4 [00:03<00:00,  1.32it/s, dice_loss - 0.2484, iou_score - 0.6742]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 4/4 [00:03<00:00,  1.32it/s, dice_loss - 0.2161, iou_score - 0.6901]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 4/4 [00:03<00:00,  1.32it/s, dice_loss - 0.222, iou_score - 0.6676]
#
# Epoch: 10
# train: 100%|██████████| 4/4 [00:03<00:00,  1.32it/s, dice_loss - 0.2143, iou_score - 0.67]
#
# Epoch: 11
# train: 100%|██████████| 4/4 [00:03<00:00,  1.32it/s, dice_loss - 0.1983, iou_score - 0.6856]
#
# Epoch: 12
# train: 100%|██████████| 4/4 [00:03<00:00,  1.32it/s, dice_loss - 0.1802, iou_score - 0.7106]
# Model saved!
#
# Epoch: 13
# train: 100%|██████████| 4/4 [00:03<00:00,  1.31it/s, dice_loss - 0.1735, iou_score - 0.7168]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 4/4 [00:03<00:00,  1.32it/s, dice_loss - 0.162, iou_score - 0.7323]
# Model saved!
#
# Epoch: 15
# train: 100%|██████████| 4/4 [00:03<00:00,  1.31it/s, dice_loss - 0.1861, iou_score - 0.6984]
#
# Epoch: 16
# train: 100%|██████████| 4/4 [00:03<00:00,  1.32it/s, dice_loss - 0.1833, iou_score - 0.7004]
#
# Epoch: 17
# train: 100%|██████████| 4/4 [00:03<00:00,  1.30it/s, dice_loss - 0.1738, iou_score - 0.7115]
#
# Epoch: 18
# train: 100%|██████████| 4/4 [00:03<00:00,  1.31it/s, dice_loss - 0.1613, iou_score - 0.7295]
#
# Epoch: 19
# train: 100%|██████████| 4/4 [00:03<00:00,  1.30it/s, dice_loss - 0.175, iou_score - 0.7089]
#
# Epoch: 20
# train: 100%|██████████| 4/4 [00:03<00:00,  1.31it/s, dice_loss - 0.179, iou_score - 0.7064]
#
# Epoch: 21
# train: 100%|██████████| 4/4 [00:03<00:00,  1.31it/s, dice_loss - 0.1522, iou_score - 0.7428]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 4/4 [00:03<00:00,  1.29it/s, dice_loss - 0.164, iou_score - 0.7266]
#
# Epoch: 23
# train: 100%|██████████| 4/4 [00:03<00:00,  1.31it/s, dice_loss - 0.1456, iou_score - 0.7519]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 4/4 [00:03<00:00,  1.28it/s, dice_loss - 0.1337, iou_score - 0.7698]
# Model saved!
#
# Epoch: 25
# train: 100%|██████████| 4/4 [00:03<00:00,  1.29it/s, dice_loss - 0.1867, iou_score - 0.6941]
#
# Epoch: 26
# train: 100%|██████████| 4/4 [00:03<00:00,  1.30it/s, dice_loss - 0.2002, iou_score - 0.6717]
#
# Epoch: 27
# train: 100%|██████████| 4/4 [00:03<00:00,  1.18it/s, dice_loss - 0.1802, iou_score - 0.7001]
#
# Epoch: 28
# train: 100%|██████████| 4/4 [00:03<00:00,  1.14it/s, dice_loss - 0.198, iou_score - 0.6742]
#
# Epoch: 29
# train: 100%|██████████| 4/4 [00:03<00:00,  1.29it/s, dice_loss - 0.1789, iou_score - 0.7033]
#
# Epoch: 30
# train: 100%|██████████| 4/4 [00:03<00:00,  1.28it/s, dice_loss - 0.1624, iou_score - 0.7259]
#
# Epoch: 31
# train: 100%|██████████| 4/4 [00:03<00:00,  1.28it/s, dice_loss - 0.1567, iou_score - 0.7343]
#
# Epoch: 32
# train: 100%|██████████| 4/4 [00:03<00:00,  1.28it/s, dice_loss - 0.1652, iou_score - 0.7216]
#
# Epoch: 33
# train: 100%|██████████| 4/4 [00:03<00:00,  1.27it/s, dice_loss - 0.1551, iou_score - 0.7359]
#
# Epoch: 34
# train: 100%|██████████| 4/4 [00:03<00:00,  1.28it/s, dice_loss - 0.1584, iou_score - 0.7312]
#
# Epoch: 35
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.1433, iou_score - 0.7536]
#
# Epoch: 36
# train: 100%|██████████| 4/4 [00:03<00:00,  1.27it/s, dice_loss - 0.1392, iou_score - 0.7598]
#
# Epoch: 37
# train: 100%|██████████| 4/4 [00:03<00:00,  1.27it/s, dice_loss - 0.197, iou_score - 0.6846]
#
# Epoch: 38
# train: 100%|██████████| 4/4 [00:03<00:00,  1.27it/s, dice_loss - 0.1372, iou_score - 0.7626]
#
# Epoch: 39
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.1326, iou_score - 0.7701]
# Model saved!
#
# Epoch: 40
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.1347, iou_score - 0.7667]
#
# Epoch: 41
# train: 100%|██████████| 4/4 [00:03<00:00,  1.27it/s, dice_loss - 0.1272, iou_score - 0.7782]
# Model saved!
#
# Epoch: 42
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.1251, iou_score - 0.7813]
# Model saved!
#
# Epoch: 43
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.1687, iou_score - 0.7165]
#
# Epoch: 44
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.1188, iou_score - 0.791]
# Model saved!
#
# Epoch: 45
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.1306, iou_score - 0.7733]
#
# Epoch: 46
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.1302, iou_score - 0.7734]
#
# Epoch: 47
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.1148, iou_score - 0.7973]
# Model saved!
#
# Epoch: 48
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.1202, iou_score - 0.7895]
#
# Epoch: 49
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.1138, iou_score - 0.7985]
# Model saved!
#
# Epoch: 50
# train: 100%|██████████| 4/4 [00:03<00:00,  1.24it/s, dice_loss - 0.1063, iou_score - 0.8111]
# Model saved!
#
# Epoch: 51
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.1076, iou_score - 0.8096]
#
# Epoch: 52
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.1036, iou_score - 0.8152]
# Model saved!
#
# Epoch: 53
# train: 100%|██████████| 4/4 [00:03<00:00,  1.24it/s, dice_loss - 0.1113, iou_score - 0.8028]
#
# Epoch: 54
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.1107, iou_score - 0.8039]
#
# Epoch: 55
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.1042, iou_score - 0.8144]
#
# Epoch: 56
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.1003, iou_score - 0.8205]
# Model saved!
#
# Epoch: 57
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.09857, iou_score - 0.8232]
# Model saved!
#
# Epoch: 58
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.1019, iou_score - 0.8181]
#
# Epoch: 59
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.0972, iou_score - 0.8257]
# Model saved!
#
# Epoch: 60
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.09592, iou_score - 0.8274]
# Model saved!
#
# Epoch: 61
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.09762, iou_score - 0.8248]
#
# Epoch: 62
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.09462, iou_score - 0.8298]
# Model saved!
#
# Epoch: 63
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.0912, iou_score - 0.8354]
# Model saved!
#
# Epoch: 64
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.0934, iou_score - 0.8317]
#
# Epoch: 65
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.08887, iou_score - 0.8392]
# Model saved!
#
# Epoch: 66
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.09328, iou_score - 0.8319]
#
# Epoch: 67
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.09141, iou_score - 0.8351]
#
# Epoch: 68
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.08896, iou_score - 0.8389]
#
# Epoch: 69
# train: 100%|██████████| 4/4 [00:03<00:00,  1.27it/s, dice_loss - 0.08861, iou_score - 0.8396]
# Model saved!
#
# Epoch: 70
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.08469, iou_score - 0.846]
# Model saved!
#
# Epoch: 71
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.08682, iou_score - 0.8424]
#
# Epoch: 72
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.08317, iou_score - 0.8486]
# Model saved!
#
# Epoch: 73
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.08339, iou_score - 0.8483]
#
# Epoch: 74
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.08405, iou_score - 0.8474]
#
# Epoch: 75
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.08818, iou_score - 0.8406]
#
# Epoch: 76
# train: 100%|██████████| 4/4 [00:03<00:00,  1.24it/s, dice_loss - 0.08763, iou_score - 0.8412]
#
# Epoch: 77
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.08421, iou_score - 0.8474]
#
# Epoch: 78
# train: 100%|██████████| 4/4 [00:03<00:00,  1.24it/s, dice_loss - 0.08491, iou_score - 0.8453]
#
# Epoch: 79
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.08881, iou_score - 0.8397]
#
# Epoch: 80
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.09108, iou_score - 0.8354]
#
# Epoch: 81
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.09959, iou_score - 0.8215]
#
# Epoch: 82
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.08675, iou_score - 0.8423]
#
# Epoch: 83
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.08961, iou_score - 0.8373]
#
# Epoch: 84
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.09058, iou_score - 0.8365]
#
# Epoch: 85
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.08545, iou_score - 0.8444]
#
# Epoch: 86
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.08749, iou_score - 0.8415]
#
# Epoch: 87
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.08844, iou_score - 0.8393]
#
# Epoch: 88
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.09219, iou_score - 0.8333]
#
# Epoch: 89
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.08255, iou_score - 0.8491]
# Model saved!
#
# Epoch: 90
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.08054, iou_score - 0.8528]
# Model saved!
#
# Epoch: 91
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.07754, iou_score - 0.858]
# Model saved!
#
# Epoch: 92
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.07655, iou_score - 0.8598]
# Model saved!
#
# Epoch: 93
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.07973, iou_score - 0.854]
#
# Epoch: 94
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.07681, iou_score - 0.8591]
#
# Epoch: 95
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.07504, iou_score - 0.8622]
# Model saved!
#
# Epoch: 96
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.07225, iou_score - 0.8671]
# Model saved!
#
# Epoch: 97
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.07399, iou_score - 0.864]
#
# Epoch: 98
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.07273, iou_score - 0.8666]
#
# Epoch: 99
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.07027, iou_score - 0.8704]
# Model saved!
#
# Epoch: 100
# train: 100%|██████████| 4/4 [00:03<00:00,  1.24it/s, dice_loss - 0.07323, iou_score - 0.8659]
#
# Epoch: 101
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.07231, iou_score - 0.867]
#
# Epoch: 102
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.07125, iou_score - 0.8686]
#
# Epoch: 103
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.07593, iou_score - 0.8608]
#
# Epoch: 104
# train: 100%|██████████| 4/4 [00:03<00:00,  1.24it/s, dice_loss - 0.07033, iou_score - 0.8702]
#
# Epoch: 105
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.06978, iou_score - 0.8712]
# Model saved!
#
# Epoch: 106
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.07259, iou_score - 0.8665]
#
# Epoch: 107
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.0675, iou_score - 0.8752]
# Model saved!
#
# Epoch: 108
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.0672, iou_score - 0.8758]
# Model saved!
#
# Epoch: 109
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.0635, iou_score - 0.8822]
# Model saved!
#
# Epoch: 110
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.06404, iou_score - 0.8814]
#
# Epoch: 111
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.06494, iou_score - 0.8798]
#
# Epoch: 112
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.06377, iou_score - 0.8818]
#
# Epoch: 113
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.06241, iou_score - 0.8842]
# Model saved!
#
# Epoch: 114
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.06153, iou_score - 0.8858]
# Model saved!
#
# Epoch: 115
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.06267, iou_score - 0.8837]
#
# Epoch: 116
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.0644, iou_score - 0.8806]
#
# Epoch: 117
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.06417, iou_score - 0.8811]
#
# Epoch: 118
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.06129, iou_score - 0.8859]
# Model saved!
#
# Epoch: 119
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.05989, iou_score - 0.8886]
# Model saved!
#
# Epoch: 120
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.06175, iou_score - 0.8853]
#
# Epoch: 121
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.0582, iou_score - 0.8917]
# Model saved!
#
# Epoch: 122
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.05937, iou_score - 0.8893]
#
# Epoch: 123
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.05782, iou_score - 0.8922]
# Model saved!
#
# Epoch: 124
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.0562, iou_score - 0.8952]
# Model saved!
#
# Epoch: 125
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.05596, iou_score - 0.8956]
# Model saved!
#
# Epoch: 126
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.05893, iou_score - 0.8904]
#
# Epoch: 127
# train: 100%|██████████| 4/4 [00:03<00:00,  1.24it/s, dice_loss - 0.05697, iou_score - 0.8937]
#
# Epoch: 128
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.0559, iou_score - 0.8956]
# Model saved!
#
# Epoch: 129
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.05534, iou_score - 0.8968]
# Model saved!
#
# Epoch: 130
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.05537, iou_score - 0.8965]
#
# Epoch: 131
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.05492, iou_score - 0.8975]
# Model saved!
#
# Epoch: 132
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.0595, iou_score - 0.8892]
#
# Epoch: 133
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.06979, iou_score - 0.8708]
#
# Epoch: 134
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.06378, iou_score - 0.8816]
#
# Epoch: 135
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.06011, iou_score - 0.888]
#
# Epoch: 136
# train: 100%|██████████| 4/4 [00:03<00:00,  1.24it/s, dice_loss - 0.06013, iou_score - 0.888]
#
# Epoch: 137
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.05586, iou_score - 0.8957]
#
# Epoch: 138
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.05389, iou_score - 0.8994]
# Model saved!
#
# Epoch: 139
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.05359, iou_score - 0.8998]
# Model saved!
#
# Epoch: 140
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.05532, iou_score - 0.897]
#
# Epoch: 141
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.0592, iou_score - 0.8905]
#
# Epoch: 142
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.0558, iou_score - 0.8957]
#
# Epoch: 143
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.05185, iou_score - 0.9031]
# Model saved!
#
# Epoch: 144
# train: 100%|██████████| 4/4 [00:03<00:00,  1.24it/s, dice_loss - 0.05366, iou_score - 0.8998]
#
# Epoch: 145
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.05426, iou_score - 0.8987]
#
# Epoch: 146
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.05445, iou_score - 0.8983]
#
# Epoch: 147
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.05244, iou_score - 0.9019]
#
# Epoch: 148
# train: 100%|██████████| 4/4 [00:03<00:00,  1.26it/s, dice_loss - 0.05403, iou_score - 0.899]
#
# Epoch: 149
# train: 100%|██████████| 4/4 [00:03<00:00,  1.25it/s, dice_loss - 0.05156, iou_score - 0.9036]
# Model saved!

# %% [markdown]
# ## Visualization of test set predictions
# #### Overall test set performance

# %%
# adapted from https://github.com/qubvel/segmentation_models.pytorch/blob/master/examples/cars%20segmentation%20(camvid).ipynb

best_model = torch.load('./best_MAnet_noAug.pth')

test_epoch = smp.utils.train.ValidEpoch(
    model = best_model,
    loss = loss,
    metrics = metrics,
    device = 'cuda',
    verbose = True
)

logs = test_epoch.run(test_generator)
# Out:
# valid: 100%|██████████| 2/2 [00:00<00:00,  2.09it/s, dice_loss - 0.1835, iou_score - 0.6908]

# %% [markdown]
# #### Images with best and worst performance

# %%
! pip install torchmetrics

from torchmetrics import JaccardIndex # same as IoU used above

jaccard = JaccardIndex(num_classes = 2,
                       threshold = 0.5)

test_ious = []

for i in range(len(test)):
  img, gt_mask = test[i]
  gt_mask = gt_mask.squeeze().int()

  x_tensor = img.to('cuda').unsqueeze(0)

  pred = best_model.predict(x_tensor)
  pred = pred.squeeze().cpu().round()
  
  test_ious.append(jaccard(pred.unsqueeze(0), gt_mask.unsqueeze(0)))

best_3 = np.argsort(test_ious)[-3:]
worst_3 = np.argsort(test_ious)[:3]
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-0.8.2-py3-none-any.whl (409 kB)
#      |████████████████████████████████| 409 kB 34.3 MB/s
# Collecting pyDeprecate==0.3.*
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.11.0+cu113)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.1->torchmetrics) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.8)
# Installing collected packages: pyDeprecate, torchmetrics
# Successfully installed pyDeprecate-0.3.2 torchmetrics-0.8.2

# %%
to_plot = list(np.hstack((best_3, worst_3)))

for i in to_plot:
  img, gt_mask = test[i]

  gt_mask = gt_mask.squeeze().int()

  x_tensor = img.to('cuda').unsqueeze(0)

  pred = best_model.predict(x_tensor)
  pred = (pred.squeeze().cpu().round())

  visualize(
      image = img.permute(1,2,0),
      target_mask = gt_mask,
      predicted_mask = pred
  )
