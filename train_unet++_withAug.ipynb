# %% [markdown]
# <a href="https://colab.research.google.com/github/ginchu/breast-cancer-image-segmentation/blob/main/train_unet%2B%2B_withAug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook trains a UNet++ model on the augmented version of the TNBC_NucleiSegmentation dataset. The UNet++ model implementation used here is provided in the popular [segmentation-models-pytorch library](https://github.com/qubvel/segmentation_models.pytorch).

# %% [markdown]
# ## Setup

# %%
! pip install segmentation-models-pytorch
! pip install wandb
# Out:
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.2.1-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 2.7 MB/s
# Collecting pretrainedmodels==0.7.4
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 5.7 MB/s
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 22.5 MB/s
# Collecting efficientnet-pytorch==0.6.3
#   Downloading efficientnet_pytorch-0.6.3.tar.gz (16 kB)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from segmentation-models-pytorch) (0.12.0+cu113)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet-pytorch==0.6.3->segmentation-models-pytorch) (1.11.0+cu113)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch) (4.64.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.6.3->segmentation-models-pytorch) (4.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (3.0.4)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.6.3-py3-none-any.whl size=12421 sha256=d5ee20f24ceba4e966756dbe71fa8dca7d92f21b278b903d792e411b3568aad2
#   Stored in directory: /root/.cache/pip/wheels/90/6b/0c/f0ad36d00310e65390b0d4c9218ae6250ac579c92540c9097a
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60965 sha256=e8c268658d9435ebfe88f4eee31f04953d2a36447ccc39eab1019916ba66b406
#   Stored in directory: /root/.cache/pip/wheels/ed/27/e8/9543d42de2740d3544db96aefef63bda3f2c1761b3334f4873
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, timm, pretrainedmodels, efficientnet-pytorch, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.6.3 munch-2.5.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.2.1 timm-0.4.12
# Collecting wandb
#   Downloading wandb-0.12.16-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 5.2 MB/s
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.12-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 67.6 MB/s
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 67.2 MB/s
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.2 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.2.0)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=55f8938a8c1020370053c5de41be9512f546c29e3279a7974e378595b198f351
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.12 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 wandb-0.12.16

# %%
# load repo and data
print('Loading data...')
! git clone https://github.com/ginchu/breast-cancer-image-segmentation.git
print('Done!')

% cd breast-cancer-image-segmentation/
# Out:
# Loading data...
# Cloning into 'breast-cancer-image-segmentation'...
# remote: Enumerating objects: 564, done.
# remote: Total 564 (delta 0), reused 0 (delta 0), pack-reused 564
# Receiving objects: 100% (564/564), 135.63 MiB | 37.23 MiB/s, done.
# Resolving deltas: 100% (31/31), done.
# Done!
# /content/breast-cancer-image-segmentation

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split

import segmentation_models_pytorch as smp
import data
import aug_data

import wandb

# %%
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
num_epochs = 150
test_split = 0.3
batch_size = 8
#SEED = 42
lr = 0.003

# %% [markdown]
# ## **D**ata

# %%
data = aug_data.AugDataset()
print(len(data))
print(data[1][0].shape)
# Out:
# 220
# torch.Size([3, 512, 512])

# %% [markdown]
# Generate train and test indices, then create data loaders for train and test sets

# %%
train_indices, test_indices, _, _ = train_test_split(
    range(len(data)),
    data.y,
    test_size=test_split
)

train = Subset(data, train_indices)
test = Subset(data, test_indices)

train_generator = DataLoader(train, batch_size=batch_size, shuffle=True)
test_generator = DataLoader(test, batch_size=batch_size, shuffle=True)

train_size, test_size = len(train), len(test)
print(train_size, test_size)
# Out:
# 154 66

# %%
# helper function for data visualization
# from https://github.com/qubvel/segmentation_models.pytorch/blob/master/examples/cars%20segmentation%20(camvid).ipynb

def visualize(**images):
    """Plot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

img, mask = data[3]
visualize(
    image=img.permute(2,1,0),
    target_mask=mask.squeeze().permute(1,0)
)

img, mask = data[20]
visualize(
    image=img.permute(2,1,0),
    target_mask=mask.squeeze().permute(1,0)
)

# %% [markdown]
# ## **M**odel

# %%
ENCODER = 'resnet34' # default for UNet++
ENCODER_WEIGHTS = 'imagenet' # default for UNet++

model = smp.UnetPlusPlus(encoder_name = ENCODER,
                         encoder_weights = ENCODER_WEIGHTS,
                         in_channels = 3,
                         classes = 1,
                         activation = 'sigmoid')

# %% [markdown]
# ## **L**oss

# %%
loss = smp.utils.losses.DiceLoss()

metrics = [
           smp.utils.metrics.IoU(threshold=0.5)
]

# %% [markdown]
# ## **O**ptimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Training loop

# %%
config_dict = dict(
    data = 'aug',
    epochs = num_epochs,
    batch_size = batch_size,
    dataset_len = len(data),
    test_split = test_split,
    lr = lr
)

wandb.init(project = 'BIA final', entity = 'weiss', config = config_dict)

train_epoch = smp.utils.train.TrainEpoch(
    model,
    loss = loss,
    metrics = metrics,
    optimizer = optimizer,
    device = 'cuda',
    verbose = True
)

tr_loss = []

max_score = 0

for epoch in range(num_epochs):
  
  print('\nEpoch: {}'. format(epoch))

  train_logs = train_epoch.run(train_generator)

  if max_score < train_logs['iou_score']:
    max_score = train_logs['iou_score']
    torch.save(model, './best_UNetPlusPlus_aug.pth')
    print('Model saved!')

  tr_loss.append(train_logs)

  wandb.log({'Epoch Dice Loss': train_logs['dice_loss'],
             'Epoch IoU Score': train_logs['iou_score'],
             'Best IoU Score': max_score})
# Out:
# Finishing last run (ID:1mkyowls) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Best IoU Score</td><td>▁█</td></tr><tr><td>Epoch Dice Loss</td><td>█▁</td></tr><tr><td>Epoch IoU Score</td><td>▁█</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Best IoU Score</td><td>0.56195</td></tr><tr><td>Epoch Dice Loss</td><td>0.33312</td></tr><tr><td>Epoch IoU Score</td><td>0.56195</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">avid-rain-11</strong>: <a href="https://wandb.ai/weiss/BIA%20final/runs/1mkyowls" target="_blank">https://wandb.ai/weiss/BIA%20final/runs/1mkyowls</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220514_161309-1mkyowls/logs</code>
# Successfully finished last run (ID:1mkyowls). Initializing new run:<br/>
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/breast-cancer-image-segmentation/wandb/run-20220514_161505-1a9v0hx2</code>
# Syncing run <strong><a href="https://wandb.ai/weiss/BIA%20final/runs/1a9v0hx2" target="_blank">giddy-yogurt-12</a></strong> to <a href="https://wandb.ai/weiss/BIA%20final" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Epoch: 0
# train: 100%|██████████| 20/20 [00:22<00:00,  1.12s/it, dice_loss - 0.4926, iou_score - 0.4446]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 20/20 [00:22<00:00,  1.14s/it, dice_loss - 0.3008, iou_score - 0.5593]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 20/20 [00:22<00:00,  1.15s/it, dice_loss - 0.2783, iou_score - 0.5765]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 20/20 [00:22<00:00,  1.14s/it, dice_loss - 0.2484, iou_score - 0.6092]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 20/20 [00:22<00:00,  1.15s/it, dice_loss - 0.2354, iou_score - 0.6244]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 20/20 [00:22<00:00,  1.14s/it, dice_loss - 0.2248, iou_score - 0.6382]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.2398, iou_score - 0.6191]
#
# Epoch: 7
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.2351, iou_score - 0.627]
#
# Epoch: 8
# train: 100%|██████████| 20/20 [00:23<00:00,  1.16s/it, dice_loss - 0.2228, iou_score - 0.6395]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.2093, iou_score - 0.6575]
# Model saved!
#
# Epoch: 10
# train: 100%|██████████| 20/20 [00:23<00:00,  1.15s/it, dice_loss - 0.205, iou_score - 0.663]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.2037, iou_score - 0.6668]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.2144, iou_score - 0.6499]
#
# Epoch: 13
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.2134, iou_score - 0.6516]
#
# Epoch: 14
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.206, iou_score - 0.6612]
#
# Epoch: 15
# train: 100%|██████████| 20/20 [00:23<00:00,  1.16s/it, dice_loss - 0.2194, iou_score - 0.6501]
#
# Epoch: 16
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.2321, iou_score - 0.6268]
#
# Epoch: 17
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.2357, iou_score - 0.6241]
#
# Epoch: 18
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.2117, iou_score - 0.6544]
#
# Epoch: 19
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1985, iou_score - 0.6714]
# Model saved!
#
# Epoch: 20
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.2041, iou_score - 0.6657]
#
# Epoch: 21
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1965, iou_score - 0.6747]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1869, iou_score - 0.6872]
# Model saved!
#
# Epoch: 23
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1867, iou_score - 0.6877]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1761, iou_score - 0.7039]
# Model saved!
#
# Epoch: 25
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1804, iou_score - 0.6969]
#
# Epoch: 26
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.2057, iou_score - 0.6627]
#
# Epoch: 27
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.2209, iou_score - 0.6495]
#
# Epoch: 28
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1906, iou_score - 0.6849]
#
# Epoch: 29
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1818, iou_score - 0.697]
#
# Epoch: 30
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1744, iou_score - 0.7059]
# Model saved!
#
# Epoch: 31
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1719, iou_score - 0.7098]
# Model saved!
#
# Epoch: 32
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1732, iou_score - 0.7099]
# Model saved!
#
# Epoch: 33
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1631, iou_score - 0.7218]
# Model saved!
#
# Epoch: 34
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1631, iou_score - 0.7222]
# Model saved!
#
# Epoch: 35
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1622, iou_score - 0.7233]
# Model saved!
#
# Epoch: 36
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1834, iou_score - 0.694]
#
# Epoch: 37
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1681, iou_score - 0.7146]
#
# Epoch: 38
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1565, iou_score - 0.7314]
# Model saved!
#
# Epoch: 39
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1669, iou_score - 0.7188]
#
# Epoch: 40
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1647, iou_score - 0.72]
#
# Epoch: 41
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.161, iou_score - 0.7252]
#
# Epoch: 42
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.157, iou_score - 0.7314]
# Model saved!
#
# Epoch: 43
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1507, iou_score - 0.7401]
# Model saved!
#
# Epoch: 44
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1562, iou_score - 0.7338]
#
# Epoch: 45
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1471, iou_score - 0.7458]
# Model saved!
#
# Epoch: 46
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1518, iou_score - 0.7398]
#
# Epoch: 47
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1458, iou_score - 0.7488]
# Model saved!
#
# Epoch: 48
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1718, iou_score - 0.7222]
#
# Epoch: 49
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1437, iou_score - 0.7513]
# Model saved!
#
# Epoch: 50
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1507, iou_score - 0.7406]
#
# Epoch: 51
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1452, iou_score - 0.7491]
#
# Epoch: 52
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1622, iou_score - 0.7312]
#
# Epoch: 53
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.145, iou_score - 0.7501]
#
# Epoch: 54
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1411, iou_score - 0.7558]
# Model saved!
#
# Epoch: 55
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1492, iou_score - 0.7426]
#
# Epoch: 56
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.146, iou_score - 0.7471]
#
# Epoch: 57
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1446, iou_score - 0.7497]
#
# Epoch: 58
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1505, iou_score - 0.7415]
#
# Epoch: 59
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.14, iou_score - 0.7567]
# Model saved!
#
# Epoch: 60
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1404, iou_score - 0.7558]
#
# Epoch: 61
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1352, iou_score - 0.7637]
# Model saved!
#
# Epoch: 62
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1307, iou_score - 0.7711]
# Model saved!
#
# Epoch: 63
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.129, iou_score - 0.7746]
# Model saved!
#
# Epoch: 64
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1335, iou_score - 0.767]
#
# Epoch: 65
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1353, iou_score - 0.7645]
#
# Epoch: 66
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1324, iou_score - 0.7695]
#
# Epoch: 67
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1327, iou_score - 0.7689]
#
# Epoch: 68
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1337, iou_score - 0.769]
#
# Epoch: 69
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1388, iou_score - 0.761]
#
# Epoch: 70
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1283, iou_score - 0.7743]
#
# Epoch: 71
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1265, iou_score - 0.778]
# Model saved!
#
# Epoch: 72
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1237, iou_score - 0.782]
# Model saved!
#
# Epoch: 73
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1445, iou_score - 0.7594]
#
# Epoch: 74
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.124, iou_score - 0.7827]
# Model saved!
#
# Epoch: 75
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1191, iou_score - 0.7897]
# Model saved!
#
# Epoch: 76
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1224, iou_score - 0.7849]
#
# Epoch: 77
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1216, iou_score - 0.7867]
#
# Epoch: 78
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1218, iou_score - 0.7852]
#
# Epoch: 79
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1172, iou_score - 0.7929]
# Model saved!
#
# Epoch: 80
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1178, iou_score - 0.7927]
#
# Epoch: 81
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1153, iou_score - 0.7953]
# Model saved!
#
# Epoch: 82
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1181, iou_score - 0.7916]
#
# Epoch: 83
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1166, iou_score - 0.7933]
#
# Epoch: 84
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1132, iou_score - 0.7986]
# Model saved!
#
# Epoch: 85
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1194, iou_score - 0.7908]
#
# Epoch: 86
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1347, iou_score - 0.7747]
#
# Epoch: 87
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1156, iou_score - 0.7956]
#
# Epoch: 88
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1243, iou_score - 0.7819]
#
# Epoch: 89
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1197, iou_score - 0.7891]
#
# Epoch: 90
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1131, iou_score - 0.8]
# Model saved!
#
# Epoch: 91
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1129, iou_score - 0.7987]
#
# Epoch: 92
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1188, iou_score - 0.7925]
#
# Epoch: 93
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.108, iou_score - 0.8077]
# Model saved!
#
# Epoch: 94
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1171, iou_score - 0.7948]
#
# Epoch: 95
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1146, iou_score - 0.7987]
#
# Epoch: 96
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1029, iou_score - 0.8154]
# Model saved!
#
# Epoch: 97
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1045, iou_score - 0.8128]
#
# Epoch: 98
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1166, iou_score - 0.7946]
#
# Epoch: 99
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1156, iou_score - 0.795]
#
# Epoch: 100
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1159, iou_score - 0.7947]
#
# Epoch: 101
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.112, iou_score - 0.8023]
#
# Epoch: 102
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1062, iou_score - 0.8099]
#
# Epoch: 103
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1063, iou_score - 0.8099]
#
# Epoch: 104
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1054, iou_score - 0.8121]
#
# Epoch: 105
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1172, iou_score - 0.7955]
#
# Epoch: 106
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1072, iou_score - 0.8091]
#
# Epoch: 107
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1058, iou_score - 0.8117]
#
# Epoch: 108
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1096, iou_score - 0.8043]
#
# Epoch: 109
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1109, iou_score - 0.8054]
#
# Epoch: 110
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.2005, iou_score - 0.6686]
#
# Epoch: 111
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.177, iou_score - 0.7021]
#
# Epoch: 112
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1735, iou_score - 0.7147]
#
# Epoch: 113
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1732, iou_score - 0.7099]
#
# Epoch: 114
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1421, iou_score - 0.7557]
#
# Epoch: 115
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1268, iou_score - 0.777]
#
# Epoch: 116
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1219, iou_score - 0.7862]
#
# Epoch: 117
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1159, iou_score - 0.7954]
#
# Epoch: 118
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1087, iou_score - 0.8054]
#
# Epoch: 119
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1144, iou_score - 0.7969]
#
# Epoch: 120
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1096, iou_score - 0.8057]
#
# Epoch: 121
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1058, iou_score - 0.8116]
#
# Epoch: 122
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1167, iou_score - 0.7935]
#
# Epoch: 123
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1129, iou_score - 0.8005]
#
# Epoch: 124
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1054, iou_score - 0.8108]
#
# Epoch: 125
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1104, iou_score - 0.803]
#
# Epoch: 126
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1023, iou_score - 0.8161]
# Model saved!
#
# Epoch: 127
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.09885, iou_score - 0.8228]
# Model saved!
#
# Epoch: 128
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1041, iou_score - 0.8156]
#
# Epoch: 129
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.09821, iou_score - 0.8235]
# Model saved!
#
# Epoch: 130
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1007, iou_score - 0.8201]
#
# Epoch: 131
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.09437, iou_score - 0.8296]
# Model saved!
#
# Epoch: 132
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1013, iou_score - 0.8181]
#
# Epoch: 133
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1029, iou_score - 0.8164]
#
# Epoch: 134
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1016, iou_score - 0.8178]
#
# Epoch: 135
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.1011, iou_score - 0.8191]
#
# Epoch: 136
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.1088, iou_score - 0.8102]
#
# Epoch: 137
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.09748, iou_score - 0.8256]
#
# Epoch: 138
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.09447, iou_score - 0.8295]
#
# Epoch: 139
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.1242, iou_score - 0.7951]
#
# Epoch: 140
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.103, iou_score - 0.8169]
#
# Epoch: 141
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.09721, iou_score - 0.825]
#
# Epoch: 142
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.1026, iou_score - 0.8173]
#
# Epoch: 143
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.09233, iou_score - 0.833]
# Model saved!
#
# Epoch: 144
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.09349, iou_score - 0.8313]
#
# Epoch: 145
# train: 100%|██████████| 20/20 [00:23<00:00,  1.20s/it, dice_loss - 0.09922, iou_score - 0.8226]
#
# Epoch: 146
# train: 100%|██████████| 20/20 [00:23<00:00,  1.18s/it, dice_loss - 0.09221, iou_score - 0.8332]
# Model saved!
#
# Epoch: 147
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.09076, iou_score - 0.8362]
# Model saved!
#
# Epoch: 148
# train: 100%|██████████| 20/20 [00:23<00:00,  1.19s/it, dice_loss - 0.09317, iou_score - 0.8323]
#
# Epoch: 149
# train: 100%|██████████| 20/20 [00:23<00:00,  1.17s/it, dice_loss - 0.09034, iou_score - 0.8366]
# Model saved!

# %% [markdown]
# ## Visualization of test set predictions
# #### Overall test set performance

# %%
# adapted from https://github.com/qubvel/segmentation_models.pytorch/blob/master/examples/cars%20segmentation%20(camvid).ipynb

best_model = torch.load('./best_UNetPlusPlus_aug.pth')

test_epoch = smp.utils.train.ValidEpoch(
    model = best_model,
    loss = loss,
    metrics = metrics,
    device = 'cuda',
    verbose = True
)

logs = test_epoch.run(test_generator)
# Out:
# valid: 100%|██████████| 9/9 [00:04<00:00,  1.95it/s, dice_loss - 0.2053, iou_score - 0.6612]

# %% [markdown]
# #### Images with best and worst performance

# %%
! pip install torchmetrics

from torchmetrics import JaccardIndex # same as IoU used above

jaccard = JaccardIndex(num_classes = 2,
                       threshold = 0.5)

test_ious = []

for i in range(len(test)):
  img, gt_mask = test[i]
  gt_mask = gt_mask.squeeze().int()

  x_tensor = img.to('cuda').unsqueeze(0)

  pred = best_model.predict(x_tensor)
  pred = pred.squeeze().cpu().round()
  
  test_ious.append(jaccard(pred.unsqueeze(0), gt_mask.unsqueeze(0)))

best_3 = np.argsort(test_ious)[-3:]
worst_3 = np.argsort(test_ious)[:3]
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-0.8.2-py3-none-any.whl (409 kB)
#      |████████████████████████████████| 409 kB 5.2 MB/s
# Collecting pyDeprecate==0.3.*
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.11.0+cu113)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.1->torchmetrics) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.8)
# Installing collected packages: pyDeprecate, torchmetrics
# Successfully installed pyDeprecate-0.3.2 torchmetrics-0.8.2

# %%
to_plot = list(np.hstack((best_3, worst_3)))

for i in to_plot:
  img, gt_mask = test[i]

  gt_mask = gt_mask.squeeze().int()

  x_tensor = img.to('cuda').unsqueeze(0)

  pred = best_model.predict(x_tensor)
  pred = (pred.squeeze().cpu().round())

  visualize(
      image = img.permute(1,2,0),
      target_mask = gt_mask,
      predicted_mask = pred
  )
