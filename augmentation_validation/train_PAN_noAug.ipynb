# %% [markdown]
# <a href="https://colab.research.google.com/github/ginchu/breast-cancer-image-segmentation/blob/main/train_pan_noAug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook trains a [Pyramid Attention Network (PAN)](https://arxiv.org/abs/1805.10180) model on the non-augmented version of the TNBC_NucleiSegmentation dataset. The PAN model implementation used here is provided in the popular [segmentation-models-pytorch library](https://github.com/qubvel/segmentation_models.pytorch).

# %% [markdown]
# ## Setup

# %%
! pip install segmentation-models-pytorch
! pip install wandb
# Out:
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.2.1-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 2.9 MB/s
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 61.8 MB/s
# Collecting efficientnet-pytorch==0.6.3
#   Downloading efficientnet_pytorch-0.6.3.tar.gz (16 kB)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from segmentation-models-pytorch) (0.12.0+cu113)
# Collecting pretrainedmodels==0.7.4
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 4.6 MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet-pytorch==0.6.3->segmentation-models-pytorch) (1.11.0+cu113)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch) (4.64.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.6.3->segmentation-models-pytorch) (4.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch) (1.15.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (3.0.4)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.6.3-py3-none-any.whl size=12421 sha256=6dcafd8509044f4b444769249fab6936217e681b61ec3833d3bbc4e64c586e6f
#   Stored in directory: /root/.cache/pip/wheels/90/6b/0c/f0ad36d00310e65390b0d4c9218ae6250ac579c92540c9097a
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60965 sha256=b42055161c8326ce75932496d45c95900122f2858fd352c563755490c701277b
#   Stored in directory: /root/.cache/pip/wheels/ed/27/e8/9543d42de2740d3544db96aefef63bda3f2c1761b3334f4873
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, timm, pretrainedmodels, efficientnet-pytorch, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.6.3 munch-2.5.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.2.1 timm-0.4.12
# Collecting wandb
#   Downloading wandb-0.12.16-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 5.1 MB/s
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 59.1 MB/s
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.12-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 65.4 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.2.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.1 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=2a82431ade200e16c822877e0f8e72a8a5097cd93f252c89a9549337d17bb04d
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.12 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 wandb-0.12.16

# %%
# load repo and data
print('Loading data...')
! git clone https://github.com/ginchu/breast-cancer-image-segmentation.git
print('Done!')

% cd breast-cancer-image-segmentation/
# Out:
# Loading data...
# Cloning into 'breast-cancer-image-segmentation'...
# remote: Enumerating objects: 599, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 599 (delta 13), reused 32 (delta 10), pack-reused 564
# Receiving objects: 100% (599/599), 327.50 MiB | 41.54 MiB/s, done.
# Resolving deltas: 100% (44/44), done.
# Checking out files: 100% (560/560), done.
# Done!
# /content/breast-cancer-image-segmentation

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split

import segmentation_models_pytorch as smp
import data
import aug_data

import wandb

# %%
wandb.login()
# Out:
# wandb: Currently logged in as: weiss. Use `wandb login --relogin` to force relogin
# True

# %%
num_epochs = 150
test_split = 0.3
batch_size = 8
#SEED = 42
lr = 0.003

# %% [markdown]
# ## **D**ata

# %%
data = data.Dataset()
print(len(data))
print(data[1][0].shape)
# Out:
# 47
# torch.Size([3, 512, 512])

# %% [markdown]
# Generate train and test indices, then create data loaders for train and test sets

# %%
train_indices, test_indices, _, _ = train_test_split(
    range(len(data)),
    data.y,
    test_size=test_split
)

train = Subset(data, train_indices)
test = Subset(data, test_indices)

train_generator = DataLoader(train, batch_size=batch_size, shuffle=True)
test_generator = DataLoader(test, batch_size=batch_size, shuffle=True)

train_size, test_size = len(train), len(test)
print(train_size, test_size)
# Out:
# 32 15

# %%
# helper function for data visualization
# from https://github.com/qubvel/segmentation_models.pytorch/blob/master/examples/cars%20segmentation%20(camvid).ipynb

def visualize(**images):
    """Plot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

img, mask = data[3]
visualize(
    image=img.permute(2,1,0),
    target_mask=mask.squeeze().permute(1,0)
)

img, mask = data[20]
visualize(
    image=img.permute(2,1,0),
    target_mask=mask.squeeze().permute(1,0)
)

# %% [markdown]
# ## **M**odel

# %%
ENCODER = 'resnet34' # default for PAN
ENCODER_WEIGHTS = 'imagenet' # default for PAN

model = smp.PAN(encoder_name = ENCODER,
                encoder_weights = ENCODER_WEIGHTS,
                in_channels = 3,
                classes = 1,
                activation = 'sigmoid')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]

# %% [markdown]
# ## **L**oss

# %%
loss = smp.utils.losses.DiceLoss()

metrics = [
           smp.utils.metrics.IoU(threshold=0.5)
]

# %% [markdown]
# ## **O**ptimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Training loop

# %%
config_dict = dict(
    data = 'noAug',
    epochs = num_epochs,
    batch_size = batch_size,
    dataset_len = len(data),
    test_split = test_split,
    lr = lr
)

wandb.init(project = 'BIA final', entity = 'weiss', config = config_dict)

train_epoch = smp.utils.train.TrainEpoch(
    model,
    loss = loss,
    metrics = metrics,
    optimizer = optimizer,
    device = 'cuda',
    verbose = True
)

tr_loss = []

max_score = 0

for epoch in range(num_epochs):
  
  print('\nEpoch: {}'. format(epoch))

  train_logs = train_epoch.run(train_generator)

  if max_score < train_logs['iou_score']:
    max_score = train_logs['iou_score']
    torch.save(model, './best_PAN_noAug.pth')
    print('Model saved!')

  tr_loss.append(train_logs)

  wandb.log({'Epoch Dice Loss': train_logs['dice_loss'],
             'Epoch IoU Score': train_logs['iou_score'],
             'Best IoU Score': max_score})
# Out:
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/breast-cancer-image-segmentation/wandb/run-20220515_011633-sftl6ofu</code>
# Syncing run <strong><a href="https://wandb.ai/weiss/BIA%20final/runs/sftl6ofu" target="_blank">tough-firefly-17</a></strong> to <a href="https://wandb.ai/weiss/BIA%20final" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Epoch: 0
# train: 100%|██████████| 4/4 [00:03<00:00,  1.27it/s, dice_loss - 0.6957, iou_score - 0.186]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 4/4 [00:02<00:00,  1.52it/s, dice_loss - 0.5361, iou_score - 0.324]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 4/4 [00:02<00:00,  1.51it/s, dice_loss - 0.4509, iou_score - 0.404]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 4/4 [00:02<00:00,  1.50it/s, dice_loss - 0.3684, iou_score - 0.4979]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 4/4 [00:02<00:00,  1.36it/s, dice_loss - 0.3491, iou_score - 0.5126]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 4/4 [00:02<00:00,  1.51it/s, dice_loss - 0.3146, iou_score - 0.5478]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.3014, iou_score - 0.5611]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 4/4 [00:02<00:00,  1.50it/s, dice_loss - 0.2914, iou_score - 0.5713]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 4/4 [00:02<00:00,  1.53it/s, dice_loss - 0.281, iou_score - 0.5792]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 4/4 [00:02<00:00,  1.36it/s, dice_loss - 0.2587, iou_score - 0.6058]
# Model saved!
#
# Epoch: 10
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.2522, iou_score - 0.6131]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.2649, iou_score - 0.5967]
#
# Epoch: 12
# train: 100%|██████████| 4/4 [00:02<00:00,  1.47it/s, dice_loss - 0.2493, iou_score - 0.6184]
# Model saved!
#
# Epoch: 13
# train: 100%|██████████| 4/4 [00:02<00:00,  1.47it/s, dice_loss - 0.2508, iou_score - 0.6137]
#
# Epoch: 14
# train: 100%|██████████| 4/4 [00:02<00:00,  1.47it/s, dice_loss - 0.2303, iou_score - 0.6404]
# Model saved!
#
# Epoch: 15
# train: 100%|██████████| 4/4 [00:02<00:00,  1.47it/s, dice_loss - 0.2324, iou_score - 0.6375]
#
# Epoch: 16
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.2243, iou_score - 0.6467]
# Model saved!
#
# Epoch: 17
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.2308, iou_score - 0.6394]
#
# Epoch: 18
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.213, iou_score - 0.6634]
# Model saved!
#
# Epoch: 19
# train: 100%|██████████| 4/4 [00:02<00:00,  1.49it/s, dice_loss - 0.2066, iou_score - 0.67]
# Model saved!
#
# Epoch: 20
# train: 100%|██████████| 4/4 [00:02<00:00,  1.48it/s, dice_loss - 0.2027, iou_score - 0.6766]
# Model saved!
#
# Epoch: 21
# train: 100%|██████████| 4/4 [00:02<00:00,  1.48it/s, dice_loss - 0.2513, iou_score - 0.6108]
#
# Epoch: 22
# train: 100%|██████████| 4/4 [00:02<00:00,  1.49it/s, dice_loss - 0.2055, iou_score - 0.6706]
#
# Epoch: 23
# train: 100%|██████████| 4/4 [00:02<00:00,  1.49it/s, dice_loss - 0.2314, iou_score - 0.6362]
#
# Epoch: 24
# train: 100%|██████████| 4/4 [00:02<00:00,  1.49it/s, dice_loss - 0.2241, iou_score - 0.648]
#
# Epoch: 25
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.2006, iou_score - 0.6778]
# Model saved!
#
# Epoch: 26
# train: 100%|██████████| 4/4 [00:02<00:00,  1.48it/s, dice_loss - 0.2016, iou_score - 0.6742]
#
# Epoch: 27
# train: 100%|██████████| 4/4 [00:02<00:00,  1.51it/s, dice_loss - 0.1972, iou_score - 0.682]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████| 4/4 [00:02<00:00,  1.48it/s, dice_loss - 0.2071, iou_score - 0.6665]
#
# Epoch: 29
# train: 100%|██████████| 4/4 [00:02<00:00,  1.48it/s, dice_loss - 0.1912, iou_score - 0.6894]
# Model saved!
#
# Epoch: 30
# train: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s, dice_loss - 0.1894, iou_score - 0.6913]
# Model saved!
#
# Epoch: 31
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.1853, iou_score - 0.6976]
# Model saved!
#
# Epoch: 32
# train: 100%|██████████| 4/4 [00:02<00:00,  1.42it/s, dice_loss - 0.1799, iou_score - 0.706]
# Model saved!
#
# Epoch: 33
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.2018, iou_score - 0.6746]
#
# Epoch: 34
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.1832, iou_score - 0.7004]
#
# Epoch: 35
# train: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s, dice_loss - 0.1844, iou_score - 0.6983]
#
# Epoch: 36
# train: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s, dice_loss - 0.1898, iou_score - 0.6897]
#
# Epoch: 37
# train: 100%|██████████| 4/4 [00:02<00:00,  1.42it/s, dice_loss - 0.1805, iou_score - 0.7055]
#
# Epoch: 38
# train: 100%|██████████| 4/4 [00:02<00:00,  1.42it/s, dice_loss - 0.209, iou_score - 0.6643]
#
# Epoch: 39
# train: 100%|██████████| 4/4 [00:02<00:00,  1.42it/s, dice_loss - 0.1883, iou_score - 0.6942]
#
# Epoch: 40
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.1891, iou_score - 0.6931]
#
# Epoch: 41
# train: 100%|██████████| 4/4 [00:02<00:00,  1.48it/s, dice_loss - 0.2093, iou_score - 0.6657]
#
# Epoch: 42
# train: 100%|██████████| 4/4 [00:02<00:00,  1.47it/s, dice_loss - 0.197, iou_score - 0.6822]
#
# Epoch: 43
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.2008, iou_score - 0.6733]
#
# Epoch: 44
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.1896, iou_score - 0.6907]
#
# Epoch: 45
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.2058, iou_score - 0.6675]
#
# Epoch: 46
# train: 100%|██████████| 4/4 [00:02<00:00,  1.47it/s, dice_loss - 0.2015, iou_score - 0.6736]
#
# Epoch: 47
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.1986, iou_score - 0.6784]
#
# Epoch: 48
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.1822, iou_score - 0.7015]
#
# Epoch: 49
# train: 100%|██████████| 4/4 [00:02<00:00,  1.47it/s, dice_loss - 0.1844, iou_score - 0.6996]
#
# Epoch: 50
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.1762, iou_score - 0.7104]
# Model saved!
#
# Epoch: 51
# train: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s, dice_loss - 0.1712, iou_score - 0.717]
# Model saved!
#
# Epoch: 52
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.169, iou_score - 0.7194]
# Model saved!
#
# Epoch: 53
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1742, iou_score - 0.7134]
#
# Epoch: 54
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1681, iou_score - 0.722]
# Model saved!
#
# Epoch: 55
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1603, iou_score - 0.7318]
# Model saved!
#
# Epoch: 56
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1765, iou_score - 0.7093]
#
# Epoch: 57
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1649, iou_score - 0.7248]
#
# Epoch: 58
# train: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s, dice_loss - 0.1624, iou_score - 0.729]
#
# Epoch: 59
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1557, iou_score - 0.739]
# Model saved!
#
# Epoch: 60
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1503, iou_score - 0.7478]
# Model saved!
#
# Epoch: 61
# train: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s, dice_loss - 0.149, iou_score - 0.7498]
# Model saved!
#
# Epoch: 62
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.168, iou_score - 0.7227]
#
# Epoch: 63
# train: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s, dice_loss - 0.166, iou_score - 0.7253]
#
# Epoch: 64
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.1647, iou_score - 0.7249]
#
# Epoch: 65
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.1644, iou_score - 0.7253]
#
# Epoch: 66
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.1628, iou_score - 0.7295]
#
# Epoch: 67
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.1514, iou_score - 0.7464]
#
# Epoch: 68
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.1488, iou_score - 0.7501]
# Model saved!
#
# Epoch: 69
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.147, iou_score - 0.7529]
# Model saved!
#
# Epoch: 70
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.1408, iou_score - 0.7624]
# Model saved!
#
# Epoch: 71
# train: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s, dice_loss - 0.144, iou_score - 0.757]
#
# Epoch: 72
# train: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s, dice_loss - 0.1393, iou_score - 0.7639]
# Model saved!
#
# Epoch: 73
# train: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s, dice_loss - 0.1407, iou_score - 0.7619]
#
# Epoch: 74
# train: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s, dice_loss - 0.1323, iou_score - 0.7748]
# Model saved!
#
# Epoch: 75
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1324, iou_score - 0.7749]
# Model saved!
#
# Epoch: 76
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1415, iou_score - 0.761]
#
# Epoch: 77
# train: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s, dice_loss - 0.1316, iou_score - 0.777]
# Model saved!
#
# Epoch: 78
# train: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s, dice_loss - 0.1307, iou_score - 0.7779]
# Model saved!
#
# Epoch: 79
# train: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s, dice_loss - 0.1333, iou_score - 0.7742]
#
# Epoch: 80
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1312, iou_score - 0.776]
#
# Epoch: 81
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.1292, iou_score - 0.7795]
# Model saved!
#
# Epoch: 82
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.1241, iou_score - 0.7888]
# Model saved!
#
# Epoch: 83
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.1221, iou_score - 0.7914]
# Model saved!
#
# Epoch: 84
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.1254, iou_score - 0.787]
#
# Epoch: 85
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.1218, iou_score - 0.7925]
# Model saved!
#
# Epoch: 86
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.1256, iou_score - 0.786]
#
# Epoch: 87
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.1235, iou_score - 0.7896]
#
# Epoch: 88
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.1686, iou_score - 0.7236]
#
# Epoch: 89
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.158, iou_score - 0.7347]
#
# Epoch: 90
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.1474, iou_score - 0.75]
#
# Epoch: 91
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.1413, iou_score - 0.7606]
#
# Epoch: 92
# train: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s, dice_loss - 0.1348, iou_score - 0.7697]
#
# Epoch: 93
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1248, iou_score - 0.7865]
#
# Epoch: 94
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1226, iou_score - 0.7905]
#
# Epoch: 95
# train: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s, dice_loss - 0.1196, iou_score - 0.7958]
# Model saved!
#
# Epoch: 96
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1155, iou_score - 0.8024]
# Model saved!
#
# Epoch: 97
# train: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s, dice_loss - 0.1139, iou_score - 0.8054]
# Model saved!
#
# Epoch: 98
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1121, iou_score - 0.8082]
# Model saved!
#
# Epoch: 99
# train: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s, dice_loss - 0.1115, iou_score - 0.8099]
# Model saved!
#
# Epoch: 100
# train: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s, dice_loss - 0.1069, iou_score - 0.8171]
# Model saved!
#
# Epoch: 101
# train: 100%|██████████| 4/4 [00:02<00:00,  1.42it/s, dice_loss - 0.1114, iou_score - 0.8088]
#
# Epoch: 102
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.1104, iou_score - 0.8116]
#
# Epoch: 103
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.1064, iou_score - 0.8177]
# Model saved!
#
# Epoch: 104
# train: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s, dice_loss - 0.1052, iou_score - 0.8187]
# Model saved!
#
# Epoch: 105
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.1029, iou_score - 0.8229]
# Model saved!
#
# Epoch: 106
# train: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s, dice_loss - 0.1039, iou_score - 0.8218]
#
# Epoch: 107
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.1019, iou_score - 0.8253]
# Model saved!
#
# Epoch: 108
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.1002, iou_score - 0.8272]
# Model saved!
#
# Epoch: 109
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.0972, iou_score - 0.8321]
# Model saved!
#
# Epoch: 110
# train: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s, dice_loss - 0.09724, iou_score - 0.8324]
# Model saved!
#
# Epoch: 111
# train: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s, dice_loss - 0.09797, iou_score - 0.8307]
#
# Epoch: 112
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.0964, iou_score - 0.833]
# Model saved!
#
# Epoch: 113
# train: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s, dice_loss - 0.0977, iou_score - 0.8312]
#
# Epoch: 114
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.09925, iou_score - 0.8273]
#
# Epoch: 115
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.1015, iou_score - 0.8239]
#
# Epoch: 116
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.09434, iou_score - 0.8365]
# Model saved!
#
# Epoch: 117
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.09879, iou_score - 0.8288]
#
# Epoch: 118
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.0927, iou_score - 0.8391]
# Model saved!
#
# Epoch: 119
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.09288, iou_score - 0.8392]
# Model saved!
#
# Epoch: 120
# train: 100%|██████████| 4/4 [00:02<00:00,  1.38it/s, dice_loss - 0.09101, iou_score - 0.8418]
# Model saved!
#
# Epoch: 121
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.08798, iou_score - 0.8473]
# Model saved!
#
# Epoch: 122
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.08934, iou_score - 0.8451]
#
# Epoch: 123
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.08715, iou_score - 0.849]
# Model saved!
#
# Epoch: 124
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.08644, iou_score - 0.8507]
# Model saved!
#
# Epoch: 125
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.08664, iou_score - 0.8496]
#
# Epoch: 126
# train: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s, dice_loss - 0.08726, iou_score - 0.8486]
#
# Epoch: 127
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.08621, iou_score - 0.8501]
#
# Epoch: 128
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.08561, iou_score - 0.8513]
# Model saved!
#
# Epoch: 129
# train: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s, dice_loss - 0.08549, iou_score - 0.8514]
# Model saved!
#
# Epoch: 130
# train: 100%|██████████| 4/4 [00:02<00:00,  1.43it/s, dice_loss - 0.08584, iou_score - 0.8502]
#
# Epoch: 131
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.0844, iou_score - 0.8529]
# Model saved!
#
# Epoch: 132
# train: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s, dice_loss - 0.08191, iou_score - 0.8572]
# Model saved!
#
# Epoch: 133
# train: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s, dice_loss - 0.08157, iou_score - 0.8578]
# Model saved!
#
# Epoch: 134
# train: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s, dice_loss - 0.08081, iou_score - 0.859]
# Model saved!
#
# Epoch: 135
# train: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s, dice_loss - 0.07975, iou_score - 0.8609]
# Model saved!
#
# Epoch: 136
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.07803, iou_score - 0.8641]
# Model saved!
#
# Epoch: 137
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.07756, iou_score - 0.8646]
# Model saved!
#
# Epoch: 138
# train: 100%|██████████| 4/4 [00:02<00:00,  1.40it/s, dice_loss - 0.07866, iou_score - 0.8639]
#
# Epoch: 139
# train: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s, dice_loss - 0.07497, iou_score - 0.8695]
# Model saved!
#
# Epoch: 140
# train: 100%|██████████| 4/4 [00:02<00:00,  1.39it/s, dice_loss - 0.07087, iou_score - 0.8775]
# Model saved!
#
# Epoch: 141
# train: 100%|██████████| 4/4 [00:02<00:00,  1.41it/s, dice_loss - 0.07106, iou_score - 0.8763]
#
# Epoch: 142
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.07073, iou_score - 0.8766]
#
# Epoch: 143
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.07759, iou_score - 0.8646]
#
# Epoch: 144
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.08066, iou_score - 0.8573]
#
# Epoch: 145
# train: 100%|██████████| 4/4 [00:02<00:00,  1.45it/s, dice_loss - 0.07553, iou_score - 0.8678]
#
# Epoch: 146
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.0718, iou_score - 0.8743]
#
# Epoch: 147
# train: 100%|██████████| 4/4 [00:02<00:00,  1.46it/s, dice_loss - 0.08256, iou_score - 0.8553]
#
# Epoch: 148
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.07669, iou_score - 0.865]
#
# Epoch: 149
# train: 100%|██████████| 4/4 [00:02<00:00,  1.44it/s, dice_loss - 0.07875, iou_score - 0.8614]

# %% [markdown]
# ## Visualization of test set predictions
# #### Overall test set performance

# %%
# adapted from https://github.com/qubvel/segmentation_models.pytorch/blob/master/examples/cars%20segmentation%20(camvid).ipynb

best_model = torch.load('./best_PAN_noAug.pth')

test_epoch = smp.utils.train.ValidEpoch(
    model = best_model,
    loss = loss,
    metrics = metrics,
    device = 'cuda',
    verbose = True
)

logs = test_epoch.run(test_generator)
# Out:
# valid: 100%|██████████| 2/2 [00:01<00:00,  1.72it/s, dice_loss - 0.1991, iou_score - 0.6713]

# %% [markdown]
# #### Images with best and worst performance

# %%
! pip install torchmetrics

from torchmetrics import JaccardIndex # same as IoU used above

jaccard = JaccardIndex(num_classes = 2,
                       threshold = 0.5)

test_ious = []

for i in range(len(test)):
  img, gt_mask = test[i]
  gt_mask = gt_mask.squeeze().int()

  x_tensor = img.to('cuda').unsqueeze(0)

  pred = best_model.predict(x_tensor)
  pred = pred.squeeze().cpu().round()
  
  test_ious.append(jaccard(pred.unsqueeze(0), gt_mask.unsqueeze(0)))

best_3 = np.argsort(test_ious)[-3:]
worst_3 = np.argsort(test_ious)[:3]
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-0.8.2-py3-none-any.whl (409 kB)
#      |████████████████████████████████| 409 kB 4.8 MB/s
# Collecting pyDeprecate==0.3.*
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.11.0+cu113)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.1->torchmetrics) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.8)
# Installing collected packages: pyDeprecate, torchmetrics
# Successfully installed pyDeprecate-0.3.2 torchmetrics-0.8.2

# %%
to_plot = list(np.hstack((best_3, worst_3)))

for i in to_plot:
  img, gt_mask = test[i]

  gt_mask = gt_mask.squeeze().int()

  x_tensor = img.to('cuda').unsqueeze(0)

  pred = best_model.predict(x_tensor)
  pred = (pred.squeeze().cpu().round())

  visualize(
      image = img.permute(1,2,0),
      target_mask = gt_mask,
      predicted_mask = pred
  )
