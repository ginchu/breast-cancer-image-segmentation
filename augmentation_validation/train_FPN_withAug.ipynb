# %% [markdown]
# <a href="https://colab.research.google.com/github/ginchu/breast-cancer-image-segmentation/blob/main/train_fpn_withAug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook trains an [FPN](http://presentations.cocodataset.org/COCO17-Stuff-FAIR.pdf) model, a type of fully convolutional neural network, on the augmented version of the TNBC_NucleiSegmentation dataset. The FPN model implementation used here is provided in the popular [segmentation-models-pytorch library](https://github.com/qubvel/segmentation_models.pytorch).

# %% [markdown]
# ## Setup

# %%
! pip install segmentation-models-pytorch
! pip install wandb
# Out:
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.2.1-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 2.8 MB/s
# Collecting efficientnet-pytorch==0.6.3
#   Downloading efficientnet_pytorch-0.6.3.tar.gz (16 kB)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from segmentation-models-pytorch) (0.12.0+cu113)
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 37.5 MB/s
# Collecting pretrainedmodels==0.7.4
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 6.2 MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet-pytorch==0.6.3->segmentation-models-pytorch) (1.11.0+cu113)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch) (4.64.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.6.3->segmentation-models-pytorch) (4.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (3.0.4)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.6.3-py3-none-any.whl size=12421 sha256=9986c61887387f263e7bfc938b888ca7c157935d294cbe4e64ec788e44621502
#   Stored in directory: /root/.cache/pip/wheels/90/6b/0c/f0ad36d00310e65390b0d4c9218ae6250ac579c92540c9097a
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60965 sha256=623a729fe688eb34d3f266777d13ec3711c5d64e618238605e6bc268cc5846d4
#   Stored in directory: /root/.cache/pip/wheels/ed/27/e8/9543d42de2740d3544db96aefef63bda3f2c1761b3334f4873
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, timm, pretrainedmodels, efficientnet-pytorch, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.6.3 munch-2.5.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.2.1 timm-0.4.12
# Collecting wandb
#   Downloading wandb-0.12.16-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 5.3 MB/s
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 62.1 MB/s
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.12-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 69.9 MB/s
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.2.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.0 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=12c7af5e636a8fd22eae7fee36e9313da09d458a7039c0cf202f1313591905d2
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.12 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 wandb-0.12.16

# %%
# load repo and data
print('Loading data...')
! git clone https://github.com/ginchu/breast-cancer-image-segmentation.git
print('Done!')

% cd breast-cancer-image-segmentation/
# Out:
# Loading data...
# Cloning into 'breast-cancer-image-segmentation'...
# remote: Enumerating objects: 587, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 587 (delta 8), reused 23 (delta 8), pack-reused 564
# Receiving objects: 100% (587/587), 322.38 MiB | 40.61 MiB/s, done.
# Resolving deltas: 100% (39/39), done.
# Checking out files: 100% (557/557), done.
# Done!
# /content/breast-cancer-image-segmentation

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split

import segmentation_models_pytorch as smp
import data
import aug_data

import wandb

# %%
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
num_epochs = 150
test_split = 0.3
batch_size = 8
#SEED = 42
lr = 0.003

# %% [markdown]
# ## **D**ata

# %%
data = aug_data.AugDataset()
print(len(data))
print(data[1][0].shape)
# Out:
# 220
# torch.Size([3, 512, 512])

# %% [markdown]
# Generate train and test indices, then create data loaders for train and test sets

# %%
train_indices, test_indices, _, _ = train_test_split(
    range(len(data)),
    data.y,
    test_size=test_split
)

train = Subset(data, train_indices)
test = Subset(data, test_indices)

train_generator = DataLoader(train, batch_size=batch_size, shuffle=True)
test_generator = DataLoader(test, batch_size=batch_size, shuffle=True)

train_size, test_size = len(train), len(test)
print(train_size, test_size)
# Out:
# 154 66

# %%
# helper function for data visualization
# from https://github.com/qubvel/segmentation_models.pytorch/blob/master/examples/cars%20segmentation%20(camvid).ipynb

def visualize(**images):
    """Plot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

img, mask = data[3]
visualize(
    image=img.permute(2,1,0),
    target_mask=mask.squeeze().permute(1,0)
)

img, mask = data[20]
visualize(
    image=img.permute(2,1,0),
    target_mask=mask.squeeze().permute(1,0)
)

# %% [markdown]
# ## **M**odel

# %%
ENCODER = 'resnet34' # default for FPN
ENCODER_WEIGHTS = 'imagenet' # default for FPN

model = smp.FPN(encoder_name = ENCODER,
                encoder_weights = ENCODER_WEIGHTS,
                in_channels = 3,
                classes = 1,
                activation = 'sigmoid')

# %% [markdown]
# ## **L**oss

# %%
loss = smp.utils.losses.DiceLoss()

metrics = [
           smp.utils.metrics.IoU(threshold=0.5)
]

# %% [markdown]
# ## **O**ptimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Training loop

# %%
config_dict = dict(
    data = 'aug',
    epochs = num_epochs,
    batch_size = batch_size,
    dataset_len = len(data),
    test_split = test_split,
    lr = lr
)

wandb.init(project = 'BIA final', entity = 'weiss', config = config_dict)

train_epoch = smp.utils.train.TrainEpoch(
    model,
    loss = loss,
    metrics = metrics,
    optimizer = optimizer,
    device = 'cuda',
    verbose = True
)

tr_loss = []

max_score = 0

for epoch in range(num_epochs):
  
  print('\nEpoch: {}'. format(epoch))

  train_logs = train_epoch.run(train_generator)

  if max_score < train_logs['iou_score']:
    max_score = train_logs['iou_score']
    torch.save(model, './best_FPN_aug.pth')
    print('Model saved!')

  tr_loss.append(train_logs)

  wandb.log({'Epoch Dice Loss': train_logs['dice_loss'],
             'Epoch IoU Score': train_logs['iou_score'],
             'Best IoU Score': max_score})
# Out:
# wandb: Currently logged in as: weiss. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/breast-cancer-image-segmentation/wandb/run-20220514_200254-4jv1o46k</code>
# Syncing run <strong><a href="https://wandb.ai/weiss/BIA%20final/runs/4jv1o46k" target="_blank">driven-terrain-13</a></strong> to <a href="https://wandb.ai/weiss/BIA%20final" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Epoch: 0
# train: 100%|██████████| 20/20 [00:12<00:00,  1.62it/s, dice_loss - 0.7468, iou_score - 0.1465]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 20/20 [00:11<00:00,  1.77it/s, dice_loss - 0.747, iou_score - 0.1455]
#
# Epoch: 2
# train: 100%|██████████| 20/20 [00:11<00:00,  1.78it/s, dice_loss - 0.7522, iou_score - 0.1423]
#
# Epoch: 3
# train: 100%|██████████| 20/20 [00:11<00:00,  1.77it/s, dice_loss - 0.7454, iou_score - 0.1471]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 20/20 [00:11<00:00,  1.76it/s, dice_loss - 0.7453, iou_score - 0.1477]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 20/20 [00:11<00:00,  1.75it/s, dice_loss - 0.711, iou_score - 0.1723]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 20/20 [00:11<00:00,  1.75it/s, dice_loss - 0.3839, iou_score - 0.4538]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 20/20 [00:11<00:00,  1.75it/s, dice_loss - 0.3151, iou_score - 0.5258]
# Model saved!
#
# Epoch: 8
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.3105, iou_score - 0.5312]
# Model saved!
#
# Epoch: 9
# train: 100%|██████████| 20/20 [00:11<00:00,  1.70it/s, dice_loss - 0.2969, iou_score - 0.5467]
# Model saved!
#
# Epoch: 10
# train: 100%|██████████| 20/20 [00:11<00:00,  1.70it/s, dice_loss - 0.2899, iou_score - 0.5553]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.2888, iou_score - 0.5573]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.2864, iou_score - 0.5598]
# Model saved!
#
# Epoch: 13
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.2743, iou_score - 0.5739]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.2607, iou_score - 0.5913]
# Model saved!
#
# Epoch: 15
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.2509, iou_score - 0.6028]
# Model saved!
#
# Epoch: 16
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2569, iou_score - 0.5959]
#
# Epoch: 17
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2501, iou_score - 0.6032]
# Model saved!
#
# Epoch: 18
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2544, iou_score - 0.5989]
#
# Epoch: 19
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.2561, iou_score - 0.5962]
#
# Epoch: 20
# train: 100%|██████████| 20/20 [00:11<00:00,  1.68it/s, dice_loss - 0.2588, iou_score - 0.5937]
#
# Epoch: 21
# train: 100%|██████████| 20/20 [00:11<00:00,  1.70it/s, dice_loss - 0.2409, iou_score - 0.6166]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2363, iou_score - 0.6215]
# Model saved!
#
# Epoch: 23
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2435, iou_score - 0.6145]
#
# Epoch: 24
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2422, iou_score - 0.6165]
#
# Epoch: 25
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.2286, iou_score - 0.6318]
# Model saved!
#
# Epoch: 26
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.236, iou_score - 0.6252]
#
# Epoch: 27
# train: 100%|██████████| 20/20 [00:11<00:00,  1.74it/s, dice_loss - 0.2323, iou_score - 0.6269]
#
# Epoch: 28
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2252, iou_score - 0.6367]
# Model saved!
#
# Epoch: 29
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2184, iou_score - 0.6453]
# Model saved!
#
# Epoch: 30
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2236, iou_score - 0.6397]
#
# Epoch: 31
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2251, iou_score - 0.6369]
#
# Epoch: 32
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2156, iou_score - 0.6495]
# Model saved!
#
# Epoch: 33
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.2175, iou_score - 0.6468]
#
# Epoch: 34
# train: 100%|██████████| 20/20 [00:11<00:00,  1.70it/s, dice_loss - 0.2195, iou_score - 0.6452]
#
# Epoch: 35
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.2189, iou_score - 0.6449]
#
# Epoch: 36
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2109, iou_score - 0.6576]
# Model saved!
#
# Epoch: 37
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2051, iou_score - 0.6629]
# Model saved!
#
# Epoch: 38
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2115, iou_score - 0.6557]
#
# Epoch: 39
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2001, iou_score - 0.6701]
# Model saved!
#
# Epoch: 40
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.209, iou_score - 0.6597]
#
# Epoch: 41
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2092, iou_score - 0.659]
#
# Epoch: 42
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1995, iou_score - 0.6708]
# Model saved!
#
# Epoch: 43
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.2048, iou_score - 0.6639]
#
# Epoch: 44
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.2115, iou_score - 0.656]
#
# Epoch: 45
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.214, iou_score - 0.6524]
#
# Epoch: 46
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.2048, iou_score - 0.6629]
#
# Epoch: 47
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.201, iou_score - 0.6692]
#
# Epoch: 48
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1939, iou_score - 0.6803]
# Model saved!
#
# Epoch: 49
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.189, iou_score - 0.6853]
# Model saved!
#
# Epoch: 50
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1972, iou_score - 0.6745]
#
# Epoch: 51
# train: 100%|██████████| 20/20 [00:11<00:00,  1.74it/s, dice_loss - 0.1989, iou_score - 0.6716]
#
# Epoch: 52
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2036, iou_score - 0.6643]
#
# Epoch: 53
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.2007, iou_score - 0.6706]
#
# Epoch: 54
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1904, iou_score - 0.6833]
#
# Epoch: 55
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1848, iou_score - 0.6906]
# Model saved!
#
# Epoch: 56
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1919, iou_score - 0.6816]
#
# Epoch: 57
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1873, iou_score - 0.6881]
#
# Epoch: 58
# train: 100%|██████████| 20/20 [00:11<00:00,  1.70it/s, dice_loss - 0.1868, iou_score - 0.6887]
#
# Epoch: 59
# train: 100%|██████████| 20/20 [00:11<00:00,  1.70it/s, dice_loss - 0.1785, iou_score - 0.7014]
# Model saved!
#
# Epoch: 60
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1811, iou_score - 0.6969]
#
# Epoch: 61
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1804, iou_score - 0.6974]
#
# Epoch: 62
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1787, iou_score - 0.7004]
#
# Epoch: 63
# train: 100%|██████████| 20/20 [00:11<00:00,  1.74it/s, dice_loss - 0.1839, iou_score - 0.6942]
#
# Epoch: 64
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1775, iou_score - 0.7016]
# Model saved!
#
# Epoch: 65
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1721, iou_score - 0.7104]
# Model saved!
#
# Epoch: 66
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1683, iou_score - 0.7155]
# Model saved!
#
# Epoch: 67
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1695, iou_score - 0.7134]
#
# Epoch: 68
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1756, iou_score - 0.7046]
#
# Epoch: 69
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1775, iou_score - 0.7015]
#
# Epoch: 70
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1725, iou_score - 0.7092]
#
# Epoch: 71
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1917, iou_score - 0.689]
#
# Epoch: 72
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1689, iou_score - 0.7144]
#
# Epoch: 73
# train: 100%|██████████| 20/20 [00:11<00:00,  1.70it/s, dice_loss - 0.1699, iou_score - 0.713]
#
# Epoch: 74
# train: 100%|██████████| 20/20 [00:11<00:00,  1.70it/s, dice_loss - 0.1621, iou_score - 0.7249]
# Model saved!
#
# Epoch: 75
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.164, iou_score - 0.7212]
#
# Epoch: 76
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1648, iou_score - 0.7203]
#
# Epoch: 77
# train: 100%|██████████| 20/20 [00:11<00:00,  1.74it/s, dice_loss - 0.2085, iou_score - 0.6645]
#
# Epoch: 78
# train: 100%|██████████| 20/20 [00:11<00:00,  1.74it/s, dice_loss - 0.1942, iou_score - 0.6786]
#
# Epoch: 79
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1768, iou_score - 0.7033]
#
# Epoch: 80
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1622, iou_score - 0.7258]
# Model saved!
#
# Epoch: 81
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1645, iou_score - 0.7233]
#
# Epoch: 82
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1519, iou_score - 0.7411]
# Model saved!
#
# Epoch: 83
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1444, iou_score - 0.7512]
# Model saved!
#
# Epoch: 84
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.149, iou_score - 0.745]
#
# Epoch: 85
# train: 100%|██████████| 20/20 [00:11<00:00,  1.70it/s, dice_loss - 0.1533, iou_score - 0.7386]
#
# Epoch: 86
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.145, iou_score - 0.7514]
# Model saved!
#
# Epoch: 87
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.144, iou_score - 0.752]
# Model saved!
#
# Epoch: 88
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1493, iou_score - 0.7439]
#
# Epoch: 89
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1469, iou_score - 0.7493]
#
# Epoch: 90
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1404, iou_score - 0.757]
# Model saved!
#
# Epoch: 91
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.141, iou_score - 0.7568]
#
# Epoch: 92
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1483, iou_score - 0.746]
#
# Epoch: 93
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1397, iou_score - 0.7587]
# Model saved!
#
# Epoch: 94
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.141, iou_score - 0.7564]
#
# Epoch: 95
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.15, iou_score - 0.7446]
#
# Epoch: 96
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1429, iou_score - 0.7531]
#
# Epoch: 97
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1356, iou_score - 0.7656]
# Model saved!
#
# Epoch: 98
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1335, iou_score - 0.7683]
# Model saved!
#
# Epoch: 99
# train: 100%|██████████| 20/20 [00:11<00:00,  1.70it/s, dice_loss - 0.1314, iou_score - 0.771]
# Model saved!
#
# Epoch: 100
# train: 100%|██████████| 20/20 [00:11<00:00,  1.69it/s, dice_loss - 0.1279, iou_score - 0.7769]
# Model saved!
#
# Epoch: 101
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.1293, iou_score - 0.7748]
#
# Epoch: 102
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1294, iou_score - 0.775]
#
# Epoch: 103
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1278, iou_score - 0.7772]
# Model saved!
#
# Epoch: 104
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1259, iou_score - 0.7809]
# Model saved!
#
# Epoch: 105
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1259, iou_score - 0.7805]
#
# Epoch: 106
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.1237, iou_score - 0.7839]
# Model saved!
#
# Epoch: 107
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1226, iou_score - 0.7868]
# Model saved!
#
# Epoch: 108
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.125, iou_score - 0.7826]
#
# Epoch: 109
# train: 100%|██████████| 20/20 [00:11<00:00,  1.74it/s, dice_loss - 0.1247, iou_score - 0.7808]
#
# Epoch: 110
# train: 100%|██████████| 20/20 [00:11<00:00,  1.74it/s, dice_loss - 0.1268, iou_score - 0.7802]
#
# Epoch: 111
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.1251, iou_score - 0.7821]
#
# Epoch: 112
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.1169, iou_score - 0.7943]
# Model saved!
#
# Epoch: 113
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.125, iou_score - 0.7818]
#
# Epoch: 114
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1264, iou_score - 0.7807]
#
# Epoch: 115
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1195, iou_score - 0.7906]
#
# Epoch: 116
# train: 100%|██████████| 20/20 [00:11<00:00,  1.74it/s, dice_loss - 0.1153, iou_score - 0.796]
# Model saved!
#
# Epoch: 117
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1188, iou_score - 0.791]
#
# Epoch: 118
# train: 100%|██████████| 20/20 [00:11<00:00,  1.74it/s, dice_loss - 0.121, iou_score - 0.7883]
#
# Epoch: 119
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.12, iou_score - 0.7898]
#
# Epoch: 120
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1161, iou_score - 0.7957]
#
# Epoch: 121
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1184, iou_score - 0.7916]
#
# Epoch: 122
# train: 100%|██████████| 20/20 [00:11<00:00,  1.74it/s, dice_loss - 0.1149, iou_score - 0.7981]
# Model saved!
#
# Epoch: 123
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1205, iou_score - 0.7894]
#
# Epoch: 124
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1167, iou_score - 0.794]
#
# Epoch: 125
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.1164, iou_score - 0.7949]
#
# Epoch: 126
# train: 100%|██████████| 20/20 [00:11<00:00,  1.71it/s, dice_loss - 0.1218, iou_score - 0.7877]
#
# Epoch: 127
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1128, iou_score - 0.8012]
# Model saved!
#
# Epoch: 128
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1202, iou_score - 0.7898]
#
# Epoch: 129
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1448, iou_score - 0.7511]
#
# Epoch: 130
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1302, iou_score - 0.7745]
#
# Epoch: 131
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1183, iou_score - 0.792]
#
# Epoch: 132
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1151, iou_score - 0.7977]
#
# Epoch: 133
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1219, iou_score - 0.7874]
#
# Epoch: 134
# train: 100%|██████████| 20/20 [00:11<00:00,  1.74it/s, dice_loss - 0.1181, iou_score - 0.794]
#
# Epoch: 135
# train: 100%|██████████| 20/20 [00:11<00:00,  1.74it/s, dice_loss - 0.1116, iou_score - 0.8039]
# Model saved!
#
# Epoch: 136
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1078, iou_score - 0.8092]
# Model saved!
#
# Epoch: 137
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1135, iou_score - 0.7998]
#
# Epoch: 138
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1077, iou_score - 0.8089]
#
# Epoch: 139
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.112, iou_score - 0.8038]
#
# Epoch: 140
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1132, iou_score - 0.8019]
#
# Epoch: 141
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.126, iou_score - 0.7824]
#
# Epoch: 142
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1122, iou_score - 0.8029]
#
# Epoch: 143
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1161, iou_score - 0.7964]
#
# Epoch: 144
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1107, iou_score - 0.8053]
#
# Epoch: 145
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1059, iou_score - 0.8127]
# Model saved!
#
# Epoch: 146
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1178, iou_score - 0.795]
#
# Epoch: 147
# train: 100%|██████████| 20/20 [00:11<00:00,  1.73it/s, dice_loss - 0.1098, iou_score - 0.8072]
#
# Epoch: 148
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1045, iou_score - 0.8138]
# Model saved!
#
# Epoch: 149
# train: 100%|██████████| 20/20 [00:11<00:00,  1.72it/s, dice_loss - 0.1072, iou_score - 0.8095]

# %% [markdown]
# ## Visualization of test set predictions
# #### Overall test set performance

# %%
# adapted from https://github.com/qubvel/segmentation_models.pytorch/blob/master/examples/cars%20segmentation%20(camvid).ipynb

best_model = torch.load('./best_FPN_aug.pth')

test_epoch = smp.utils.train.ValidEpoch(
    model = best_model,
    loss = loss,
    metrics = metrics,
    device = 'cuda',
    verbose = True
)

logs = test_epoch.run(test_generator)
# Out:
# valid: 100%|██████████| 9/9 [00:03<00:00,  2.73it/s, dice_loss - 0.2275, iou_score - 0.6315]

# %% [markdown]
# #### Images with best and worst performance

# %%
! pip install torchmetrics

from torchmetrics import JaccardIndex # same as IoU used above

jaccard = JaccardIndex(num_classes = 2,
                       threshold = 0.5)

test_ious = []

for i in range(len(test)):
  img, gt_mask = test[i]
  gt_mask = gt_mask.squeeze().int()

  x_tensor = img.to('cuda').unsqueeze(0)

  pred = best_model.predict(x_tensor)
  pred = pred.squeeze().cpu().round()
  
  test_ious.append(jaccard(pred.unsqueeze(0), gt_mask.unsqueeze(0)))

best_3 = np.argsort(test_ious)[-3:]
worst_3 = np.argsort(test_ious)[:3]
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-0.8.2-py3-none-any.whl (409 kB)
#      |████████████████████████████████| 409 kB 5.1 MB/s
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.11.0+cu113)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Collecting pyDeprecate==0.3.*
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.1->torchmetrics) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.8)
# Installing collected packages: pyDeprecate, torchmetrics
# Successfully installed pyDeprecate-0.3.2 torchmetrics-0.8.2

# %%
to_plot = list(np.hstack((best_3, worst_3)))

for i in to_plot:
  img, gt_mask = test[i]

  gt_mask = gt_mask.squeeze().int()

  x_tensor = img.to('cuda').unsqueeze(0)

  pred = best_model.predict(x_tensor)
  pred = (pred.squeeze().cpu().round())

  visualize(
      image = img.permute(1,2,0),
      target_mask = gt_mask,
      predicted_mask = pred
  )
