# %% [markdown]
# <a href="https://colab.research.google.com/github/ginchu/breast-cancer-image-segmentation/blob/main/train_pan_withAug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook trains a [Pyramid Attention Network (PAN)](https://arxiv.org/abs/1805.10180) model on the augmented version of the TNBC_NucleiSegmentation dataset. The PAN model implementation used here is provided in the popular [segmentation-models-pytorch library](https://github.com/qubvel/segmentation_models.pytorch).

# %% [markdown]
# ## Setup

# %%
! pip install segmentation-models-pytorch
! pip install wandb
# Out:
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.2.1-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 4.5 MB/s
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from segmentation-models-pytorch) (0.12.0+cu113)
# Collecting efficientnet-pytorch==0.6.3
#   Downloading efficientnet_pytorch-0.6.3.tar.gz (16 kB)
# Collecting pretrainedmodels==0.7.4
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 3.4 MB/s
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 49.3 MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet-pytorch==0.6.3->segmentation-models-pytorch) (1.11.0+cu113)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch) (4.64.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.6.3->segmentation-models-pytorch) (4.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (7.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.21.6)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (1.24.3)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.6.3-py3-none-any.whl size=12421 sha256=cd04eebfa15be3e86847d970c51c2cdffb5c1128f3445cba943763e1be9739f1
#   Stored in directory: /root/.cache/pip/wheels/90/6b/0c/f0ad36d00310e65390b0d4c9218ae6250ac579c92540c9097a
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60965 sha256=9993db31b0f8f39629d89f98c63c1999e86c8f0c2a5926c8049ab14bc0c7b4ce
#   Stored in directory: /root/.cache/pip/wheels/ed/27/e8/9543d42de2740d3544db96aefef63bda3f2c1761b3334f4873
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, timm, pretrainedmodels, efficientnet-pytorch, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.6.3 munch-2.5.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.2.1 timm-0.4.12
# Collecting wandb
#   Downloading wandb-0.12.16-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 11.8 MB/s
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 16.3 MB/s
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.12-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 45.5 MB/s
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 2.1 MB/s
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.2.0)
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=40d2d1d17fb695835302a768da7ced3090db90919fc9fe8c1779faefc7094e9c
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.12 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 wandb-0.12.16

# %%
# load repo and data
print('Loading data...')
! git clone https://github.com/ginchu/breast-cancer-image-segmentation.git
print('Done!')

% cd breast-cancer-image-segmentation/
# Out:
# Loading data...
# Cloning into 'breast-cancer-image-segmentation'...
# remote: Enumerating objects: 593, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 593 (delta 10), reused 27 (delta 8), pack-reused 564
# Receiving objects: 100% (593/593), 325.65 MiB | 21.47 MiB/s, done.
# Resolving deltas: 100% (41/41), done.
# Checking out files: 100% (559/559), done.
# Done!
# /content/breast-cancer-image-segmentation

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split

import segmentation_models_pytorch as smp
import data
import aug_data

import wandb

# %%
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
num_epochs = 150
test_split = 0.3
batch_size = 8
#SEED = 42
lr = 0.003

# %% [markdown]
# ## **D**ata

# %%
data = aug_data.AugDataset()
print(len(data))
print(data[1][0].shape)
# Out:
# 220
# torch.Size([3, 512, 512])

# %% [markdown]
# Generate train and test indices, then create data loaders for train and test sets

# %%
train_indices, test_indices, _, _ = train_test_split(
    range(len(data)),
    data.y,
    test_size=test_split
)

train = Subset(data, train_indices)
test = Subset(data, test_indices)

train_generator = DataLoader(train, batch_size=batch_size, shuffle=True)
test_generator = DataLoader(test, batch_size=batch_size, shuffle=True)

train_size, test_size = len(train), len(test)
print(train_size, test_size)
# Out:
# 154 66

# %%
# helper function for data visualization
# from https://github.com/qubvel/segmentation_models.pytorch/blob/master/examples/cars%20segmentation%20(camvid).ipynb

def visualize(**images):
    """Plot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

img, mask = data[3]
visualize(
    image=img.permute(2,1,0),
    target_mask=mask.squeeze().permute(1,0)
)

img, mask = data[20]
visualize(
    image=img.permute(2,1,0),
    target_mask=mask.squeeze().permute(1,0)
)

# %% [markdown]
# ## **M**odel

# %%
ENCODER = 'resnet34' # default for PAN
ENCODER_WEIGHTS = 'imagenet' # default for PAN

model = smp.PAN(encoder_name = ENCODER,
                encoder_weights = ENCODER_WEIGHTS,
                in_channels = 3,
                classes = 1,
                activation = 'sigmoid')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]

# %% [markdown]
# ## **L**oss

# %%
loss = smp.utils.losses.DiceLoss()

metrics = [
           smp.utils.metrics.IoU(threshold=0.5)
]

# %% [markdown]
# ## **O**ptimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Training loop

# %%
config_dict = dict(
    data = 'aug',
    epochs = num_epochs,
    batch_size = batch_size,
    dataset_len = len(data),
    test_split = test_split,
    lr = lr
)

wandb.init(project = 'BIA final', entity = 'weiss', config = config_dict)

train_epoch = smp.utils.train.TrainEpoch(
    model,
    loss = loss,
    metrics = metrics,
    optimizer = optimizer,
    device = 'cuda',
    verbose = True
)

tr_loss = []

max_score = 0

for epoch in range(num_epochs):
  
  print('\nEpoch: {}'. format(epoch))

  train_logs = train_epoch.run(train_generator)

  if max_score < train_logs['iou_score']:
    max_score = train_logs['iou_score']
    torch.save(model, './best_PAN_aug.pth')
    print('Model saved!')

  tr_loss.append(train_logs)

  wandb.log({'Epoch Dice Loss': train_logs['dice_loss'],
             'Epoch IoU Score': train_logs['iou_score'],
             'Best IoU Score': max_score})
# Out:
# wandb: Currently logged in as: weiss. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/breast-cancer-image-segmentation/wandb/run-20220515_002408-1an9x8tl</code>
# Syncing run <strong><a href="https://wandb.ai/weiss/BIA%20final/runs/1an9x8tl" target="_blank">feasible-firefly-16</a></strong> to <a href="https://wandb.ai/weiss/BIA%20final" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Epoch: 0
# train: 100%|██████████| 20/20 [00:13<00:00,  1.47it/s, dice_loss - 0.5388, iou_score - 0.3274]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 20/20 [00:13<00:00,  1.54it/s, dice_loss - 0.3731, iou_score - 0.4742]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 20/20 [00:12<00:00,  1.61it/s, dice_loss - 0.3305, iou_score - 0.5176]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 20/20 [00:12<00:00,  1.61it/s, dice_loss - 0.3178, iou_score - 0.5287]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 20/20 [00:12<00:00,  1.61it/s, dice_loss - 0.2969, iou_score - 0.5531]
# Model saved!
#
# Epoch: 5
# train: 100%|██████████| 20/20 [00:12<00:00,  1.60it/s, dice_loss - 0.2947, iou_score - 0.5557]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.2831, iou_score - 0.5708]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.3179, iou_score - 0.5294]
#
# Epoch: 8
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.2977, iou_score - 0.5527]
#
# Epoch: 9
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2871, iou_score - 0.5639]
#
# Epoch: 10
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2796, iou_score - 0.5719]
# Model saved!
#
# Epoch: 11
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.2855, iou_score - 0.5721]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2781, iou_score - 0.5762]
# Model saved!
#
# Epoch: 13
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2622, iou_score - 0.5921]
# Model saved!
#
# Epoch: 14
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2627, iou_score - 0.5934]
# Model saved!
#
# Epoch: 15
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.2463, iou_score - 0.6123]
# Model saved!
#
# Epoch: 16
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2484, iou_score - 0.6102]
#
# Epoch: 17
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.2438, iou_score - 0.6165]
# Model saved!
#
# Epoch: 18
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2441, iou_score - 0.6153]
#
# Epoch: 19
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2657, iou_score - 0.5892]
#
# Epoch: 20
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.2677, iou_score - 0.5855]
#
# Epoch: 21
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.2556, iou_score - 0.6021]
#
# Epoch: 22
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2417, iou_score - 0.6184]
# Model saved!
#
# Epoch: 23
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2267, iou_score - 0.6377]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.225, iou_score - 0.64]
# Model saved!
#
# Epoch: 25
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2208, iou_score - 0.6459]
# Model saved!
#
# Epoch: 26
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2338, iou_score - 0.6297]
#
# Epoch: 27
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.2217, iou_score - 0.6462]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.2229, iou_score - 0.643]
#
# Epoch: 29
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2275, iou_score - 0.6377]
#
# Epoch: 30
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.2159, iou_score - 0.6515]
# Model saved!
#
# Epoch: 31
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2143, iou_score - 0.654]
# Model saved!
#
# Epoch: 32
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2082, iou_score - 0.661]
# Model saved!
#
# Epoch: 33
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2079, iou_score - 0.6621]
# Model saved!
#
# Epoch: 34
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2043, iou_score - 0.6672]
# Model saved!
#
# Epoch: 35
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2157, iou_score - 0.6526]
#
# Epoch: 36
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.2047, iou_score - 0.668]
# Model saved!
#
# Epoch: 37
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2059, iou_score - 0.6651]
#
# Epoch: 38
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2089, iou_score - 0.6612]
#
# Epoch: 39
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.2102, iou_score - 0.661]
#
# Epoch: 40
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1964, iou_score - 0.6778]
# Model saved!
#
# Epoch: 41
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1973, iou_score - 0.6776]
#
# Epoch: 42
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1946, iou_score - 0.6818]
# Model saved!
#
# Epoch: 43
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1962, iou_score - 0.6779]
#
# Epoch: 44
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1888, iou_score - 0.6884]
# Model saved!
#
# Epoch: 45
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1969, iou_score - 0.6785]
#
# Epoch: 46
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1998, iou_score - 0.6738]
#
# Epoch: 47
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.19, iou_score - 0.6871]
#
# Epoch: 48
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1879, iou_score - 0.6903]
# Model saved!
#
# Epoch: 49
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1777, iou_score - 0.705]
# Model saved!
#
# Epoch: 50
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1823, iou_score - 0.6981]
#
# Epoch: 51
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1745, iou_score - 0.7084]
# Model saved!
#
# Epoch: 52
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1952, iou_score - 0.6808]
#
# Epoch: 53
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2409, iou_score - 0.6167]
#
# Epoch: 54
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.2149, iou_score - 0.6536]
#
# Epoch: 55
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1987, iou_score - 0.6737]
#
# Epoch: 56
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1838, iou_score - 0.6947]
#
# Epoch: 57
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.1886, iou_score - 0.69]
#
# Epoch: 58
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1827, iou_score - 0.6976]
#
# Epoch: 59
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.183, iou_score - 0.6958]
#
# Epoch: 60
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.1773, iou_score - 0.7041]
#
# Epoch: 61
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1696, iou_score - 0.7162]
# Model saved!
#
# Epoch: 62
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1674, iou_score - 0.7226]
# Model saved!
#
# Epoch: 63
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1695, iou_score - 0.7175]
#
# Epoch: 64
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1623, iou_score - 0.7259]
# Model saved!
#
# Epoch: 65
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1674, iou_score - 0.7212]
#
# Epoch: 66
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1551, iou_score - 0.7369]
# Model saved!
#
# Epoch: 67
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1665, iou_score - 0.7208]
#
# Epoch: 68
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1549, iou_score - 0.7376]
# Model saved!
#
# Epoch: 69
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.155, iou_score - 0.739]
# Model saved!
#
# Epoch: 70
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1555, iou_score - 0.7382]
#
# Epoch: 71
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1494, iou_score - 0.7461]
# Model saved!
#
# Epoch: 72
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1584, iou_score - 0.734]
#
# Epoch: 73
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1633, iou_score - 0.728]
#
# Epoch: 74
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1793, iou_score - 0.7011]
#
# Epoch: 75
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1711, iou_score - 0.7136]
#
# Epoch: 76
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1693, iou_score - 0.7166]
#
# Epoch: 77
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1568, iou_score - 0.7348]
#
# Epoch: 78
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1625, iou_score - 0.7257]
#
# Epoch: 79
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.1665, iou_score - 0.7209]
#
# Epoch: 80
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1585, iou_score - 0.7335]
#
# Epoch: 81
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1752, iou_score - 0.7069]
#
# Epoch: 82
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1611, iou_score - 0.7286]
#
# Epoch: 83
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1558, iou_score - 0.7353]
#
# Epoch: 84
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.16, iou_score - 0.7314]
#
# Epoch: 85
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1494, iou_score - 0.7458]
#
# Epoch: 86
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1419, iou_score - 0.7568]
# Model saved!
#
# Epoch: 87
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.138, iou_score - 0.7635]
# Model saved!
#
# Epoch: 88
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1451, iou_score - 0.7544]
#
# Epoch: 89
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1425, iou_score - 0.7554]
#
# Epoch: 90
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1412, iou_score - 0.7587]
#
# Epoch: 91
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1417, iou_score - 0.7582]
#
# Epoch: 92
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1388, iou_score - 0.7627]
#
# Epoch: 93
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1355, iou_score - 0.7666]
# Model saved!
#
# Epoch: 94
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1376, iou_score - 0.7639]
#
# Epoch: 95
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1408, iou_score - 0.7597]
#
# Epoch: 96
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1633, iou_score - 0.7367]
#
# Epoch: 97
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1338, iou_score - 0.7696]
# Model saved!
#
# Epoch: 98
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1339, iou_score - 0.7683]
#
# Epoch: 99
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.1391, iou_score - 0.7613]
#
# Epoch: 100
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1291, iou_score - 0.7778]
# Model saved!
#
# Epoch: 101
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.127, iou_score - 0.7816]
# Model saved!
#
# Epoch: 102
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1389, iou_score - 0.7603]
#
# Epoch: 103
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1466, iou_score - 0.7493]
#
# Epoch: 104
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1366, iou_score - 0.7658]
#
# Epoch: 105
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1251, iou_score - 0.7845]
# Model saved!
#
# Epoch: 106
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1297, iou_score - 0.7769]
#
# Epoch: 107
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.2212, iou_score - 0.6408]
#
# Epoch: 108
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1962, iou_score - 0.6764]
#
# Epoch: 109
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1669, iou_score - 0.7187]
#
# Epoch: 110
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1622, iou_score - 0.7269]
#
# Epoch: 111
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.1541, iou_score - 0.7378]
#
# Epoch: 112
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1463, iou_score - 0.7499]
#
# Epoch: 113
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.1353, iou_score - 0.7664]
#
# Epoch: 114
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1346, iou_score - 0.7687]
#
# Epoch: 115
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.1367, iou_score - 0.7656]
#
# Epoch: 116
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1381, iou_score - 0.7628]
#
# Epoch: 117
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1322, iou_score - 0.7715]
#
# Epoch: 118
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1332, iou_score - 0.7706]
#
# Epoch: 119
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.1474, iou_score - 0.7514]
#
# Epoch: 120
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.1257, iou_score - 0.7826]
#
# Epoch: 121
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1241, iou_score - 0.7848]
# Model saved!
#
# Epoch: 122
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1388, iou_score - 0.7618]
#
# Epoch: 123
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1312, iou_score - 0.7746]
#
# Epoch: 124
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1246, iou_score - 0.7839]
#
# Epoch: 125
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.1241, iou_score - 0.7859]
# Model saved!
#
# Epoch: 126
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1202, iou_score - 0.7909]
# Model saved!
#
# Epoch: 127
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1277, iou_score - 0.7809]
#
# Epoch: 128
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.124, iou_score - 0.7849]
#
# Epoch: 129
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1223, iou_score - 0.7885]
#
# Epoch: 130
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1129, iou_score - 0.8024]
# Model saved!
#
# Epoch: 131
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1161, iou_score - 0.7979]
#
# Epoch: 132
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.1163, iou_score - 0.7967]
#
# Epoch: 133
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.123, iou_score - 0.7877]
#
# Epoch: 134
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1217, iou_score - 0.7893]
#
# Epoch: 135
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1206, iou_score - 0.7912]
#
# Epoch: 136
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1155, iou_score - 0.7989]
#
# Epoch: 137
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1173, iou_score - 0.7964]
#
# Epoch: 138
# train: 100%|██████████| 20/20 [00:12<00:00,  1.58it/s, dice_loss - 0.1108, iou_score - 0.8047]
# Model saved!
#
# Epoch: 139
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1172, iou_score - 0.7965]
#
# Epoch: 140
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1127, iou_score - 0.8035]
#
# Epoch: 141
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1153, iou_score - 0.7981]
#
# Epoch: 142
# train: 100%|██████████| 20/20 [00:12<00:00,  1.56it/s, dice_loss - 0.1197, iou_score - 0.7941]
#
# Epoch: 143
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1176, iou_score - 0.7947]
#
# Epoch: 144
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1329, iou_score - 0.7689]
#
# Epoch: 145
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1275, iou_score - 0.7786]
#
# Epoch: 146
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1401, iou_score - 0.7668]
#
# Epoch: 147
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1306, iou_score - 0.7746]
#
# Epoch: 148
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1171, iou_score - 0.7952]
#
# Epoch: 149
# train: 100%|██████████| 20/20 [00:12<00:00,  1.57it/s, dice_loss - 0.1108, iou_score - 0.8057]
# Model saved!

# %% [markdown]
# ## Visualization of test set predictions
# #### Overall test set performance

# %%
# adapted from https://github.com/qubvel/segmentation_models.pytorch/blob/master/examples/cars%20segmentation%20(camvid).ipynb

best_model = torch.load('./best_PAN_aug.pth')

test_epoch = smp.utils.train.ValidEpoch(
    model = best_model,
    loss = loss,
    metrics = metrics,
    device = 'cuda',
    verbose = True
)

logs = test_epoch.run(test_generator)
# Out:
# valid: 100%|██████████| 9/9 [00:03<00:00,  2.73it/s, dice_loss - 0.2083, iou_score - 0.657]

# %% [markdown]
# #### Images with best and worst performance

# %%
! pip install torchmetrics

from torchmetrics import JaccardIndex # same as IoU used above

jaccard = JaccardIndex(num_classes = 2,
                       threshold = 0.5)

test_ious = []

for i in range(len(test)):
  img, gt_mask = test[i]
  gt_mask = gt_mask.squeeze().int()

  x_tensor = img.to('cuda').unsqueeze(0)

  pred = best_model.predict(x_tensor)
  pred = pred.squeeze().cpu().round()
  
  test_ious.append(jaccard(pred.unsqueeze(0), gt_mask.unsqueeze(0)))

best_3 = np.argsort(test_ious)[-3:]
worst_3 = np.argsort(test_ious)[:3]
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-0.8.2-py3-none-any.whl (409 kB)
#      |████████████████████████████████| 409 kB 14.8 MB/s
# Collecting pyDeprecate==0.3.*
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.11.0+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.1->torchmetrics) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.8)
# Installing collected packages: pyDeprecate, torchmetrics
# Successfully installed pyDeprecate-0.3.2 torchmetrics-0.8.2

# %%
to_plot = list(np.hstack((best_3, worst_3)))

for i in to_plot:
  img, gt_mask = test[i]

  gt_mask = gt_mask.squeeze().int()

  x_tensor = img.to('cuda').unsqueeze(0)

  pred = best_model.predict(x_tensor)
  pred = (pred.squeeze().cpu().round())

  visualize(
      image = img.permute(1,2,0),
      target_mask = gt_mask,
      predicted_mask = pred
  )
