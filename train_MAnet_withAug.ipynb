# %% [markdown]
# <a href="https://colab.research.google.com/github/ginchu/breast-cancer-image-segmentation/blob/main/train_MAnet_withAug.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This notebook trains a [Multi-Scale Attention Network (MA-Net)](https://ieeexplore.ieee.org/abstract/document/9201310) model on the augmented version of the TNBC_NucleiSegmentation dataset. The MA-Net model implementation used here is provided in the popular [segmentation-models-pytorch library](https://github.com/qubvel/segmentation_models.pytorch).

# %% [markdown]
# ## Setup

# %%
! pip install segmentation-models-pytorch
! pip install wandb
# Out:
# Collecting segmentation-models-pytorch
#   Downloading segmentation_models_pytorch-0.2.1-py3-none-any.whl (88 kB)
#      |████████████████████████████████| 88 kB 2.5 MB/s
# Collecting efficientnet-pytorch==0.6.3
#   Downloading efficientnet_pytorch-0.6.3.tar.gz (16 kB)
# Requirement already satisfied: torchvision>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from segmentation-models-pytorch) (0.12.0+cu113)
# Collecting pretrainedmodels==0.7.4
#   Downloading pretrainedmodels-0.7.4.tar.gz (58 kB)
#      |████████████████████████████████| 58 kB 4.8 MB/s
# Collecting timm==0.4.12
#   Downloading timm-0.4.12-py3-none-any.whl (376 kB)
#      |████████████████████████████████| 376 kB 23.8 MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from efficientnet-pytorch==0.6.3->segmentation-models-pytorch) (1.11.0+cu113)
# Collecting munch
#   Downloading munch-2.5.0-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from pretrainedmodels==0.7.4->segmentation-models-pytorch) (4.64.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->efficientnet-pytorch==0.6.3->segmentation-models-pytorch) (4.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.5.0->segmentation-models-pytorch) (2.23.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from munch->pretrainedmodels==0.7.4->segmentation-models-pytorch) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.5.0->segmentation-models-pytorch) (2.10)
# Building wheels for collected packages: efficientnet-pytorch, pretrainedmodels
#   Building wheel for efficientnet-pytorch (setup.py) ... done
#   Created wheel for efficientnet-pytorch: filename=efficientnet_pytorch-0.6.3-py3-none-any.whl size=12421 sha256=1fedf3dc26bb12fcc73c03f044b8c4ca224955b4d8b660b091a945767f36249b
#   Stored in directory: /root/.cache/pip/wheels/90/6b/0c/f0ad36d00310e65390b0d4c9218ae6250ac579c92540c9097a
#   Building wheel for pretrainedmodels (setup.py) ... done
#   Created wheel for pretrainedmodels: filename=pretrainedmodels-0.7.4-py3-none-any.whl size=60965 sha256=23f41719961f0c8c7f2fd97f0238bf98de16394b2a52c39e49eb6cdff4871a99
#   Stored in directory: /root/.cache/pip/wheels/ed/27/e8/9543d42de2740d3544db96aefef63bda3f2c1761b3334f4873
# Successfully built efficientnet-pytorch pretrainedmodels
# Installing collected packages: munch, timm, pretrainedmodels, efficientnet-pytorch, segmentation-models-pytorch
# Successfully installed efficientnet-pytorch-0.6.3 munch-2.5.0 pretrainedmodels-0.7.4 segmentation-models-pytorch-0.2.1 timm-0.4.12
# Collecting wandb
#   Downloading wandb-0.12.16-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 4.4 MB/s
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.12-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 51.4 MB/s
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 51.6 MB/s
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.2.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.9 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Building wheels for collected packages: pathtools
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=f82c66e238c007512975261d8f1c56933a2e4de8d91b62ddd451b19b2f2d57bf
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built pathtools
# Installing collected packages: smmap, gitdb, shortuuid, setproctitle, sentry-sdk, pathtools, GitPython, docker-pycreds, wandb
# Successfully installed GitPython-3.1.27 docker-pycreds-0.4.0 gitdb-4.0.9 pathtools-0.1.2 sentry-sdk-1.5.12 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 wandb-0.12.16

# %%
# load repo and data
print('Loading data...')
! git clone https://github.com/ginchu/breast-cancer-image-segmentation.git
print('Done!')

% cd breast-cancer-image-segmentation/
# Out:
# Loading data...
# Cloning into 'breast-cancer-image-segmentation'...
# remote: Enumerating objects: 612, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 612 (delta 1), reused 9 (delta 0), pack-reused 602
# Receiving objects: 100% (612/612), 646.89 MiB | 14.70 MiB/s, done.
# Resolving deltas: 100% (47/47), done.
# Checking out files: 100% (566/566), done.
# Done!
# /content/breast-cancer-image-segmentation

# %%
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch.utils.data import DataLoader, Subset
from sklearn.model_selection import train_test_split

import segmentation_models_pytorch as smp
import data
import aug_data

import wandb

# %%
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
num_epochs = 150
test_split = 0.3
batch_size = 8
#SEED = 42
lr = 0.003

# %% [markdown]
# ## **D**ata

# %%
data = aug_data.AugDataset()
print(len(data))
print(data[1][0].shape)
# Out:
# 220
# torch.Size([3, 512, 512])

# %% [markdown]
# Generate train and test indices, then create data loaders for train and test sets

# %%
train_indices, test_indices, _, _ = train_test_split(
    range(len(data)),
    data.y,
    test_size=test_split
)

train = Subset(data, train_indices)
test = Subset(data, test_indices)

train_generator = DataLoader(train, batch_size=batch_size, shuffle=True)
test_generator = DataLoader(test, batch_size=batch_size, shuffle=True)

train_size, test_size = len(train), len(test)
print(train_size, test_size)
# Out:
# 154 66

# %%
# helper function for data visualization
# from https://github.com/qubvel/segmentation_models.pytorch/blob/master/examples/cars%20segmentation%20(camvid).ipynb

def visualize(**images):
    """Plot images in one row."""
    n = len(images)
    plt.figure(figsize=(16, 5))
    for i, (name, image) in enumerate(images.items()):
        plt.subplot(1, n, i + 1)
        plt.xticks([])
        plt.yticks([])
        plt.title(' '.join(name.split('_')).title())
        plt.imshow(image)
    plt.show()

img, mask = data[3]
visualize(
    image=img.permute(2,1,0),
    target_mask=mask.squeeze().permute(1,0)
)

img, mask = data[20]
visualize(
    image=img.permute(2,1,0),
    target_mask=mask.squeeze().permute(1,0)
)

# %% [markdown]
# ## **M**odel

# %%
ENCODER = 'resnet34' # default for MAnet
ENCODER_WEIGHTS = 'imagenet' # default for MAnet

model = smp.MAnet(encoder_name = ENCODER,
                  encoder_weights = ENCODER_WEIGHTS,
                  in_channels = 3,
                  classes = 1,
                  activation = 'sigmoid')
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
#   0%|          | 0.00/83.3M [00:00<?, ?B/s]

# %% [markdown]
# ## **L**oss

# %%
loss = smp.utils.losses.DiceLoss()

metrics = [
           smp.utils.metrics.IoU(threshold=0.5)
]

# %% [markdown]
# ## **O**ptimizer

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %% [markdown]
# ## Training loop

# %%
config_dict = dict(
    data = 'aug',
    epochs = num_epochs,
    batch_size = batch_size,
    dataset_len = len(data),
    test_split = test_split,
    lr = lr
)

wandb.init(project = 'BIA final', entity = 'weiss', config = config_dict)

train_epoch = smp.utils.train.TrainEpoch(
    model,
    loss = loss,
    metrics = metrics,
    optimizer = optimizer,
    device = 'cuda',
    verbose = True
)

tr_loss = []

max_score = 0

for epoch in range(num_epochs):
  
  print('\nEpoch: {}'. format(epoch))

  train_logs = train_epoch.run(train_generator)

  if max_score < train_logs['iou_score']:
    max_score = train_logs['iou_score']
    torch.save(model, './best_MAnet_withAug.pth')
    print('Model saved!')

  tr_loss.append(train_logs)

  wandb.log({'Epoch Dice Loss': train_logs['dice_loss'],
             'Epoch IoU Score': train_logs['iou_score'],
             'Best IoU Score': max_score})
# Out:
# wandb: Currently logged in as: weiss. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.16
# Run data is saved locally in <code>/content/breast-cancer-image-segmentation/wandb/run-20220515_183312-1ju7lsfb</code>
# Syncing run <strong><a href="https://wandb.ai/weiss/BIA%20final/runs/1ju7lsfb" target="_blank">cerulean-sun-19</a></strong> to <a href="https://wandb.ai/weiss/BIA%20final" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>
# Epoch: 0
# train: 100%|██████████| 20/20 [00:32<00:00,  1.63s/it, dice_loss - 0.54, iou_score - 0.3784]
# Model saved!
#
# Epoch: 1
# train: 100%|██████████| 20/20 [00:32<00:00,  1.64s/it, dice_loss - 0.3274, iou_score - 0.5364]
# Model saved!
#
# Epoch: 2
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.2849, iou_score - 0.568]
# Model saved!
#
# Epoch: 3
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.2728, iou_score - 0.5801]
# Model saved!
#
# Epoch: 4
# train: 100%|██████████| 20/20 [00:32<00:00,  1.64s/it, dice_loss - 0.2731, iou_score - 0.5799]
#
# Epoch: 5
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.251, iou_score - 0.6044]
# Model saved!
#
# Epoch: 6
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.2331, iou_score - 0.6268]
# Model saved!
#
# Epoch: 7
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.2419, iou_score - 0.6166]
#
# Epoch: 8
# train: 100%|██████████| 20/20 [00:32<00:00,  1.64s/it, dice_loss - 0.2328, iou_score - 0.6261]
#
# Epoch: 9
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.2541, iou_score - 0.6054]
#
# Epoch: 10
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.2471, iou_score - 0.6122]
#
# Epoch: 11
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.2222, iou_score - 0.6412]
# Model saved!
#
# Epoch: 12
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.2115, iou_score - 0.6542]
# Model saved!
#
# Epoch: 13
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.2366, iou_score - 0.6275]
#
# Epoch: 14
# train: 100%|██████████| 20/20 [00:32<00:00,  1.64s/it, dice_loss - 0.2115, iou_score - 0.6536]
#
# Epoch: 15
# train: 100%|██████████| 20/20 [00:32<00:00,  1.64s/it, dice_loss - 0.2152, iou_score - 0.6517]
#
# Epoch: 16
# train: 100%|██████████| 20/20 [00:32<00:00,  1.64s/it, dice_loss - 0.2064, iou_score - 0.6617]
# Model saved!
#
# Epoch: 17
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.209, iou_score - 0.6586]
#
# Epoch: 18
# train: 100%|██████████| 20/20 [00:32<00:00,  1.64s/it, dice_loss - 0.2025, iou_score - 0.6666]
# Model saved!
#
# Epoch: 19
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.197, iou_score - 0.6739]
# Model saved!
#
# Epoch: 20
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1973, iou_score - 0.6735]
#
# Epoch: 21
# train: 100%|██████████| 20/20 [00:33<00:00,  1.67s/it, dice_loss - 0.1939, iou_score - 0.6782]
# Model saved!
#
# Epoch: 22
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1987, iou_score - 0.6718]
#
# Epoch: 23
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1921, iou_score - 0.6799]
# Model saved!
#
# Epoch: 24
# train: 100%|██████████| 20/20 [00:32<00:00,  1.64s/it, dice_loss - 0.1942, iou_score - 0.6776]
#
# Epoch: 25
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1915, iou_score - 0.6813]
# Model saved!
#
# Epoch: 26
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1909, iou_score - 0.684]
# Model saved!
#
# Epoch: 27
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1831, iou_score - 0.6926]
# Model saved!
#
# Epoch: 28
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.189, iou_score - 0.6847]
#
# Epoch: 29
# train: 100%|██████████| 20/20 [00:33<00:00,  1.67s/it, dice_loss - 0.1931, iou_score - 0.6787]
#
# Epoch: 30
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1804, iou_score - 0.6969]
# Model saved!
#
# Epoch: 31
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1888, iou_score - 0.6857]
#
# Epoch: 32
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1968, iou_score - 0.6741]
#
# Epoch: 33
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1832, iou_score - 0.692]
#
# Epoch: 34
# train: 100%|██████████| 20/20 [00:33<00:00,  1.67s/it, dice_loss - 0.178, iou_score - 0.7004]
# Model saved!
#
# Epoch: 35
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1898, iou_score - 0.6847]
#
# Epoch: 36
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1945, iou_score - 0.6802]
#
# Epoch: 37
# train: 100%|██████████| 20/20 [00:33<00:00,  1.67s/it, dice_loss - 0.1976, iou_score - 0.6747]
#
# Epoch: 38
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1969, iou_score - 0.6748]
#
# Epoch: 39
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1839, iou_score - 0.6917]
#
# Epoch: 40
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1805, iou_score - 0.6973]
#
# Epoch: 41
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1778, iou_score - 0.7003]
#
# Epoch: 42
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1794, iou_score - 0.6984]
#
# Epoch: 43
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1915, iou_score - 0.6893]
#
# Epoch: 44
# train: 100%|██████████| 20/20 [00:32<00:00,  1.64s/it, dice_loss - 0.1758, iou_score - 0.7032]
# Model saved!
#
# Epoch: 45
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1695, iou_score - 0.7132]
# Model saved!
#
# Epoch: 46
# train: 100%|██████████| 20/20 [00:32<00:00,  1.64s/it, dice_loss - 0.1687, iou_score - 0.7147]
# Model saved!
#
# Epoch: 47
# train: 100%|██████████| 20/20 [00:32<00:00,  1.64s/it, dice_loss - 0.1641, iou_score - 0.7208]
# Model saved!
#
# Epoch: 48
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1694, iou_score - 0.7135]
#
# Epoch: 49
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1645, iou_score - 0.7199]
#
# Epoch: 50
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1737, iou_score - 0.7078]
#
# Epoch: 51
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1663, iou_score - 0.7183]
#
# Epoch: 52
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1612, iou_score - 0.7238]
# Model saved!
#
# Epoch: 53
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.157, iou_score - 0.7318]
# Model saved!
#
# Epoch: 54
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1614, iou_score - 0.7253]
#
# Epoch: 55
# train: 100%|██████████| 20/20 [00:33<00:00,  1.67s/it, dice_loss - 0.1668, iou_score - 0.7171]
#
# Epoch: 56
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1669, iou_score - 0.7163]
#
# Epoch: 57
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1829, iou_score - 0.694]
#
# Epoch: 58
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.174, iou_score - 0.7056]
#
# Epoch: 59
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1717, iou_score - 0.7094]
#
# Epoch: 60
# train: 100%|██████████| 20/20 [00:32<00:00,  1.64s/it, dice_loss - 0.1706, iou_score - 0.7119]
#
# Epoch: 61
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1559, iou_score - 0.7321]
# Model saved!
#
# Epoch: 62
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1652, iou_score - 0.7208]
#
# Epoch: 63
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1516, iou_score - 0.7399]
# Model saved!
#
# Epoch: 64
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.155, iou_score - 0.7347]
#
# Epoch: 65
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1562, iou_score - 0.7327]
#
# Epoch: 66
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1672, iou_score - 0.7182]
#
# Epoch: 67
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1492, iou_score - 0.743]
# Model saved!
#
# Epoch: 68
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1471, iou_score - 0.7467]
# Model saved!
#
# Epoch: 69
# train: 100%|██████████| 20/20 [00:33<00:00,  1.67s/it, dice_loss - 0.1532, iou_score - 0.736]
#
# Epoch: 70
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1496, iou_score - 0.7412]
#
# Epoch: 71
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1465, iou_score - 0.7468]
# Model saved!
#
# Epoch: 72
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1469, iou_score - 0.7454]
#
# Epoch: 73
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1453, iou_score - 0.7495]
# Model saved!
#
# Epoch: 74
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1466, iou_score - 0.7479]
#
# Epoch: 75
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1428, iou_score - 0.7516]
# Model saved!
#
# Epoch: 76
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1417, iou_score - 0.7544]
# Model saved!
#
# Epoch: 77
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1406, iou_score - 0.7556]
# Model saved!
#
# Epoch: 78
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1475, iou_score - 0.7459]
#
# Epoch: 79
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1429, iou_score - 0.7523]
#
# Epoch: 80
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1444, iou_score - 0.7501]
#
# Epoch: 81
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1421, iou_score - 0.7543]
#
# Epoch: 82
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1488, iou_score - 0.7437]
#
# Epoch: 83
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1815, iou_score - 0.696]
#
# Epoch: 84
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1697, iou_score - 0.7127]
#
# Epoch: 85
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.154, iou_score - 0.736]
#
# Epoch: 86
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.152, iou_score - 0.7378]
#
# Epoch: 87
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1557, iou_score - 0.7349]
#
# Epoch: 88
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1511, iou_score - 0.7407]
#
# Epoch: 89
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1748, iou_score - 0.7173]
#
# Epoch: 90
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1554, iou_score - 0.7339]
#
# Epoch: 91
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1458, iou_score - 0.748]
#
# Epoch: 92
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1415, iou_score - 0.7552]
#
# Epoch: 93
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1422, iou_score - 0.754]
#
# Epoch: 94
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1531, iou_score - 0.7371]
#
# Epoch: 95
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1514, iou_score - 0.7408]
#
# Epoch: 96
# train: 100%|██████████| 20/20 [00:32<00:00,  1.64s/it, dice_loss - 0.151, iou_score - 0.7411]
#
# Epoch: 97
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1432, iou_score - 0.7516]
#
# Epoch: 98
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1548, iou_score - 0.7395]
#
# Epoch: 99
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1387, iou_score - 0.7597]
# Model saved!
#
# Epoch: 100
# train: 100%|██████████| 20/20 [00:32<00:00,  1.64s/it, dice_loss - 0.1413, iou_score - 0.7567]
#
# Epoch: 101
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1376, iou_score - 0.7606]
# Model saved!
#
# Epoch: 102
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1356, iou_score - 0.7633]
# Model saved!
#
# Epoch: 103
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1345, iou_score - 0.7647]
# Model saved!
#
# Epoch: 104
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1353, iou_score - 0.7638]
#
# Epoch: 105
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1302, iou_score - 0.7724]
# Model saved!
#
# Epoch: 106
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.131, iou_score - 0.7709]
#
# Epoch: 107
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1363, iou_score - 0.7634]
#
# Epoch: 108
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1296, iou_score - 0.7725]
# Model saved!
#
# Epoch: 109
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1352, iou_score - 0.764]
#
# Epoch: 110
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1381, iou_score - 0.7602]
#
# Epoch: 111
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1287, iou_score - 0.7745]
# Model saved!
#
# Epoch: 112
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1315, iou_score - 0.7709]
#
# Epoch: 113
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1313, iou_score - 0.7712]
#
# Epoch: 114
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1259, iou_score - 0.7786]
# Model saved!
#
# Epoch: 115
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.124, iou_score - 0.7811]
# Model saved!
#
# Epoch: 116
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1393, iou_score - 0.7601]
#
# Epoch: 117
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1286, iou_score - 0.7749]
#
# Epoch: 118
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1313, iou_score - 0.771]
#
# Epoch: 119
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1338, iou_score - 0.7673]
#
# Epoch: 120
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1327, iou_score - 0.7689]
#
# Epoch: 121
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1294, iou_score - 0.7739]
#
# Epoch: 122
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1372, iou_score - 0.7637]
#
# Epoch: 123
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1314, iou_score - 0.7718]
#
# Epoch: 124
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1203, iou_score - 0.7884]
# Model saved!
#
# Epoch: 125
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1276, iou_score - 0.7766]
#
# Epoch: 126
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1274, iou_score - 0.7761]
#
# Epoch: 127
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1228, iou_score - 0.7835]
#
# Epoch: 128
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1321, iou_score - 0.776]
#
# Epoch: 129
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1328, iou_score - 0.7702]
#
# Epoch: 130
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1216, iou_score - 0.7858]
#
# Epoch: 131
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1229, iou_score - 0.783]
#
# Epoch: 132
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1331, iou_score - 0.769]
#
# Epoch: 133
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.119, iou_score - 0.7893]
# Model saved!
#
# Epoch: 134
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1246, iou_score - 0.7814]
#
# Epoch: 135
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1254, iou_score - 0.7793]
#
# Epoch: 136
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1187, iou_score - 0.7894]
# Model saved!
#
# Epoch: 137
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.124, iou_score - 0.782]
#
# Epoch: 138
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1259, iou_score - 0.7799]
#
# Epoch: 139
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1348, iou_score - 0.767]
#
# Epoch: 140
# train: 100%|██████████| 20/20 [00:33<00:00,  1.65s/it, dice_loss - 0.1178, iou_score - 0.7902]
# Model saved!
#
# Epoch: 141
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1193, iou_score - 0.7902]
#
# Epoch: 142
# train: 100%|██████████| 20/20 [00:32<00:00,  1.65s/it, dice_loss - 0.1183, iou_score - 0.7916]
# Model saved!
#
# Epoch: 143
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1197, iou_score - 0.7877]
#
# Epoch: 144
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1312, iou_score - 0.7735]
#
# Epoch: 145
# train: 100%|██████████| 20/20 [00:33<00:00,  1.67s/it, dice_loss - 0.1267, iou_score - 0.7782]
#
# Epoch: 146
# train: 100%|██████████| 20/20 [00:33<00:00,  1.67s/it, dice_loss - 0.1216, iou_score - 0.7866]
#
# Epoch: 147
# train: 100%|██████████| 20/20 [00:33<00:00,  1.67s/it, dice_loss - 0.1197, iou_score - 0.7891]
#
# Epoch: 148
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1374, iou_score - 0.7606]
#
# Epoch: 149
# train: 100%|██████████| 20/20 [00:33<00:00,  1.66s/it, dice_loss - 0.1395, iou_score - 0.7566]

# %% [markdown]
# ## Visualization of test set predictions
# #### Overall test set performance

# %%
# adapted from https://github.com/qubvel/segmentation_models.pytorch/blob/master/examples/cars%20segmentation%20(camvid).ipynb

best_model = torch.load('./best_MAnet_withAug.pth')

test_epoch = smp.utils.train.ValidEpoch(
    model = best_model,
    loss = loss,
    metrics = metrics,
    device = 'cuda',
    verbose = True
)

logs = test_epoch.run(test_generator)
# Out:
# valid: 100%|██████████| 9/9 [00:06<00:00,  1.40it/s, dice_loss - 0.2171, iou_score - 0.6456]

# %% [markdown]
# #### Images with best and worst performance

# %%
! pip install torchmetrics

from torchmetrics import JaccardIndex # same as IoU used above

jaccard = JaccardIndex(num_classes = 2,
                       threshold = 0.5)

test_ious = []

for i in range(len(test)):
  img, gt_mask = test[i]
  gt_mask = gt_mask.squeeze().int()

  x_tensor = img.to('cuda').unsqueeze(0)

  pred = best_model.predict(x_tensor)
  pred = pred.squeeze().cpu().round()
  
  test_ious.append(jaccard(pred.unsqueeze(0), gt_mask.unsqueeze(0)))

best_3 = np.argsort(test_ious)[-3:]
worst_3 = np.argsort(test_ious)[:3]
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-0.8.2-py3-none-any.whl (409 kB)
#      |████████████████████████████████| 409 kB 4.2 MB/s
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.11.0+cu113)
# Collecting pyDeprecate==0.3.*
#   Downloading pyDeprecate-0.3.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.3.1->torchmetrics) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.8)
# Installing collected packages: pyDeprecate, torchmetrics
# Successfully installed pyDeprecate-0.3.2 torchmetrics-0.8.2

# %%
to_plot = list(np.hstack((best_3, worst_3)))

for i in to_plot:
  img, gt_mask = test[i]

  gt_mask = gt_mask.squeeze().int()

  x_tensor = img.to('cuda').unsqueeze(0)

  pred = best_model.predict(x_tensor)
  pred = (pred.squeeze().cpu().round())

  visualize(
      image = img.permute(1,2,0),
      target_mask = gt_mask,
      predicted_mask = pred
  )
